# %%
Student_1 = '' #@param {type:"string"}  Name of student 1
Student_2 = '' #@param {type:"string"}  Name of student 2
Student_3 = '' #@param {type:"string"}  Name of student 3
Student_4 = '' #@param {type:"string"}  Name of student 4

# %% [markdown]
# # Overview
#
# This is the skeleton code file for the EEC4400 assignment. Replace the `XX`. in the name of this Jupyter notebook with your group number (this is important for correct marks to be awarded to your group). Fill in the blank cells below with the necessary code (you should work on this Jupyter notebook section by section). At the end, the entire Jupyter notebook should generate all the required results and execute without error.
#
# The text above the blank cells provides information on the functionality that needs to be implemented. You need to write Python code at places indicated by `[WriteCode]`

# %% [markdown]
# ## Install and Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

import os
import time
import numpy as np
import random
from collections import deque

import gymnasium as gym

# %% [markdown]
# # Background

# %% [markdown]
# ## Environment Exploration: Cart-Pole
#
# The **Cart-Pole environment** is a classic reinforcement learning problem where a pole is attached by an un-actuated joint to a cart. The cart moves along a frictionless track, and the goal is to balance the pole upright by applying forces to move the cart left or right.
#
# <img src="https://gymnasium.farama.org/_images/cart_pole.gif" width="400">
#
# Below is a breakdown of the base Cart-Pole environment:

# %% [markdown]
# #### - **Observation Space (*s*)**
# The observation is represented as a `ndarray` of shape `(4,)`, corresponding to:
# - **Cart Position**: Horizontal location of the cart.
# - **Cart Velocity**: Speed of the cart along the track.
# - **Pole Angle**: Angular position of the pole relative to vertical.
# - **Pole Angular Velocity**: Speed at which the pole angle changes.
#
# The observations are initialized with uniformly random values in the range `(-0.05, 0.05)`.

# %% [markdown]
# #### - **Action Space (*a*)**
# The action is a discrete value (`0` or `1`) indicating the direction of the force applied to the cart:
# - `0`: Push the cart to the left.
# - `1`: Push the cart to the right.

# %% [markdown]
# #### - **Reward Function (*r*)**
# The agent receives a reward of `+1` for each time step it successfully keeps the pole upright. The maximum achievable reward in a single episode is `500`.

# %% [markdown]
# #### - **Episode Termination (*isDone*)**
# An episode ends if any of the following conditions occur:
# 1. **Pole Angle** exceeds `±12°`.
# 2. **Cart Position** exceeds `±2.4` (the cart reaches the edge of the track).
# 3. **Truncation**: The episode reaches the maximum length of `500 steps`.

# %% [markdown]
# ## Getting Familiar with Basic Gymnasium Usage
#
# Let's observe how to interact with a Gymnasium environment.

# %% [markdown]
# The classic “agent-environment loop” pictured below is a simplified representation of reinforcement learning that Gymnasium implements.
#
# ![agt-env.png](attachment:d805e642-400b-4fa6-b924-f8fcc8ed6f53.png)
#
# The following section represents a simple episode of this loop, we will:
#
# 1. Import the base Cart-Pole environment from the gymnasium library and explore its functionality.
#
# 2. Apply modifications to make the environment more challenging by adjusting the pole's dynamics and introducing stochastic forces.
#
# 3. Sample random actions to control the cart-pole.
#
# These steps will help us understand how the environment behaves under different conditions and prepare us for implementing reinforcement learning agents in later sections.

# %%
import warnings
warnings.filterwarnings('ignore')

# Import and Explore the Environment
print("\n--- Exploring the Base Environment ---")
env = gym.make("CartPole-v1")
observation, info = env.reset()

# Print information about the environment
print(f"Initial Observation: {observation}")
print(f"Action Space: {env.action_space}")  # Discrete actions: 0 (left), 1 (right)
print(f"Observation Space: {env.observation_space}")  # State variables: cart position, etc.
# Out:
# --- Exploring the Base Environment ---
# Initial Observation: [ 0.00103025 -0.00305208  0.02931872  0.04117618]
# Action Space: Discrete(2)
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %% [markdown]
# # Define Helper Functions

# %% [markdown]
# ## Plotting Functions

# %%
# Some plotting functions
import matplotlib.pyplot as plt

def plot_eval_rwd_mean(eval_mean_list):
    """Plot evaluation reward mean."""
    if len(eval_mean_list) == 0:
        print("eval_mean_list is empty, nothing to plot.")
        return
    
    episodes = range(1, len(eval_mean_list) + 1)

    plt.figure()
    plt.plot(episodes, eval_mean_list)
    plt.xlabel("Episode")
    plt.ylabel("Evaluation Reward (mean)")
    plt.title("Evaluation Reward Mean per Episode")
    plt.grid(True)
    plt.show()


def plot_eval_rwd_var(eval_var_list):
    """Plot evaluation reward variance."""
    if len(eval_var_list) == 0:
        print("eval_var_list is empty, nothing to plot.")
        return

    episodes = range(1, len(eval_var_list) + 1)

    plt.figure()
    plt.plot(episodes, eval_var_list)
    plt.xlabel("Episode")
    plt.ylabel("Evaluation Reward (variance)")
    plt.title("Evaluation Reward Variance per Episode")
    plt.grid(True)
    plt.show()



def plot_smoothed_training_rwd(train_rwd_list, window_size=20):
    """Plot smoothed training rewards using a moving average."""
    n = len(train_rwd_list)
    if n == 0:
        print("train_rwd_list is empty, nothing to plot.")
        return
    
    # 如果 episode 数比窗口小，就把窗口缩短
    window_size = min(window_size, n)

    # 简单的滑动平均
    smoothed = []
    for i in range(n - window_size + 1):
        window = train_rwd_list[i:i + window_size]
        smoothed.append(sum(window) / window_size)

    # 对应的 episode 编号（从 window_size 开始）
    episodes = range(window_size, n + 1)

    plt.figure()
    plt.plot(episodes, smoothed)
    plt.xlabel("Episode")
    plt.ylabel(f"Training Reward (moving average, window={window_size})")
    plt.title("Smoothed Training Reward")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Evaluation Function
#
# Evaluate the learnt policy by running 5 evaluation episodes and computing the average and variance of rewards collected.

# %%
def evaluation(model, max_timesteps=500):
    eval_env = gym.make("CartPole-v1")
    state_size = eval_env.observation_space.shape[0] # Number of observations (CartPole)
    action_size = eval_env.action_space.n            # Number of possible actions
    eval_reward = []

    for i in range (5):
        round_reward = 0
        state, _ = eval_env.reset()
        state = np.reshape(state, [1, state_size])

        for i in range(max_timesteps):
            action = np.argmax(model.predict(state, verbose=0)[0])
            next_state, reward, terminated, truncated, _ = eval_env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            round_reward += reward
            state = next_state

            if terminated or truncated:
                eval_reward.append(round_reward)
                break

    eval_env.close()

    eval_reward_mean = np.sum(eval_reward)/len(eval_reward)
    eval_reward_var = np.var(eval_reward)

    return eval_reward_mean, eval_reward_var

# %% [markdown]
# # Setting up Tensorboard

# %%
def get_run_logdir(k):
    root_logdir = os.path.join(os.curdir, "eec4400_logs", k)
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

# %% [markdown]
# # Initialize Parameters

# %%
# Use the following set of NN hyperparameters for ALL FOUR baseline policies
lr =  0.001        #@param {type:"number"}               # learning rate
epoch =  1     #@param {type:"number"}               # epochs
episode = 250  #@param {type:"number"}               # episodes

epsilon = 1           #@param {type:"number"}     # Starting exploration rate
epsilon_min = 0.01    #@param {type:"number"}     # Exploration rate min
epsilon_decay = 0.995     #@param {type:"number"}     # Exploration rate decay

gamma = 0.99          #@param {type:"number"}     # Agent discount factor

# Use the following set of NN hyperparameters for Naive DQN, DQN and DDQN policies
ba =  32       #@param {type:"number"}               # batch_size

# Use the following set of RL hyperparameters for DQN and DDQN policies
target_update_freq = 50 # @param {type:"number"}    # Target network update frequency

# %% [markdown]
# # Q-Network - Baseline

# %% [markdown]
# ## Define and Compile the Neural Network
#
# A single network $Q_\theta$ (parameterized by $\theta$) is used to approximate $Q(s,a)$.
#
# The target used by Naive DQN is then:
#
# $Y^{NaiveQ}_t = R_{t+1} + \gamma Q_{\theta}(S_{t+1}, a)$
#
# The training of Q-Network does NOT rely on a Replay Buffer.

# %%
class QTablePseudoModel:
    def __init__(self, Q_table, state_bounds, num_bins):
        self.Q_table = Q_table
        self.state_bounds = state_bounds
        self.num_bins = num_bins

    def discretize_state(self, state):
        discretized = []
        for s, (low, high) in zip(state.flatten(), self.state_bounds):
            s = np.clip(s, low, high)
            bin_idx = int(np.floor((s - low) / (high - low) * self.num_bins))
            bin_idx = np.clip(bin_idx, 0, self.num_bins - 1)
            discretized.append(bin_idx)
        return discretized[0] * (self.num_bins**3) + discretized[1] * (self.num_bins**2) + discretized[2] * self.num_bins + discretized[3]

    def predict(self, state, verbose=0):
        state_discrete = self.discretize_state(state)
        q_values = self.Q_table[state_discrete].reshape(1, -1)
        return q_values

def discretize_state(state, state_bounds, num_bins):
    discretized = []
    for s, (low, high) in zip(state.flatten(), state_bounds):
        s = np.clip(s, low, high)
        bin_idx = int(np.floor((s - low) / (high - low) * num_bins))
        bin_idx = np.clip(bin_idx, 0, num_bins - 1)
        discretized.append(bin_idx)
    return discretized[0] * (num_bins**3) + discretized[1] * (num_bins**2) + discretized[2] * num_bins + discretized[3]

# Environment and Q-table initialization
env = gym.make("CartPole-v1")
action_size = env.action_space.n
state_size_continuous = env.observation_space.shape[0]

state_bounds = [
    [-2.4, 2.4],
    [-3.0, 3.0],
    [-0.209, 0.209],
    [-3.0, 3.0]
]

num_bins = 10
discrete_state_num = num_bins ** state_size_continuous
Q_table = np.zeros((discrete_state_num, action_size))

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
## Set Up Env and Train the Policy
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []
total_training_time = 0

for ep in range(episode):
    state_continuous, _ = env.reset()
    state_discrete = discretize_state(state_continuous, state_bounds, num_bins)
    total_reward = 0
    start_time = time.time()

    for _ in range(500):
        # Epsilon-greedy action selection
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            action = np.argmax(Q_table[state_discrete, :])

        # Execute action and get feedback
        next_state_continuous, reward, terminated, truncated, _ = env.step(action)
        next_state_discrete = discretize_state(next_state_continuous, state_bounds, num_bins)
        done = terminated or truncated

        # Q-table update
        current_Q = Q_table[state_discrete, action]
        target_Q = reward if done else reward + gamma * np.max(Q_table[next_state_discrete, :])
        Q_table[state_discrete, action] += lr * (target_Q - current_Q)

        # Epsilon decay
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        # State update and reward accumulation
        state_discrete = next_state_discrete
        total_reward += reward
        if done:
            break

    # Record training time
    end_time = time.time()
    total_training_time += (end_time - start_time)
    
    # Evaluate policy
    pseudo_model = QTablePseudoModel(Q_table, state_bounds, num_bins)
    eval_mean, eval_var = evaluation(pseudo_model)

    # Print log
    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward:.0f}"
          f" | Epsilon : {epsilon:.3f}"
          f" | Eval Rwd Mean: {eval_mean:.2f}"
          f" | Eval Rwd Var: {eval_var:.2f}")

    # Store log data
    train_reward_lst.append(total_reward)
    eval_reward_mean_lst.append(eval_mean)
    eval_reward_var_lst.append(eval_var)

    # Early stopping
    if eval_mean >= 500:
        print(f"Early stopping triggered at Episode {ep + 1}.")
        break

# Calculate average training time
avg_train_time = total_training_time / (ep + 1)
print(f"\nTraining time: {avg_train_time:.4f} seconds per episode")
env.close()
# Out:
# Episode 1/250 | Ep. Total Reward: 13 | Epsilon : 0.937 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.00
# Episode 2/250 | Ep. Total Reward: 26 | Epsilon : 0.822 | Eval Rwd Mean: 11.80 | Eval Rwd Var: 9.76
# Episode 3/250 | Ep. Total Reward: 28 | Epsilon : 0.715 | Eval Rwd Mean: 14.60 | Eval Rwd Var: 24.64
# Episode 4/250 | Ep. Total Reward: 29 | Epsilon : 0.618 | Eval Rwd Mean: 58.60 | Eval Rwd Var: 2552.64
# Episode 5/250 | Ep. Total Reward: 12 | Epsilon : 0.582 | Eval Rwd Mean: 16.60 | Eval Rwd Var: 59.84
# Episode 6/250 | Ep. Total Reward: 10 | Epsilon : 0.554 | Eval Rwd Mean: 31.40 | Eval Rwd Var: 892.24
# Episode 7/250 | Ep. Total Reward: 25 | Epsilon : 0.488 | Eval Rwd Mean: 16.40 | Eval Rwd Var: 25.84
# Episode 8/250 | Ep. Total Reward: 13 | Epsilon : 0.458 | Eval Rwd Mean: 27.40 | Eval Rwd Var: 134.64
# Episode 9/250 | Ep. Total Reward: 13 | Epsilon : 0.429 | Eval Rwd Mean: 48.60 | Eval Rwd Var: 2149.04
# Episode 10/250 | Ep. Total Reward: 15 | Epsilon : 0.398 | Eval Rwd Mean: 20.00 | Eval Rwd Var: 65.60
# Episode 11/250 | Ep. Total Reward: 13 | Epsilon : 0.373 | Eval Rwd Mean: 19.20 | Eval Rwd Var: 168.16
# Episode 12/250 | Ep. Total Reward: 41 | Epsilon : 0.303 | Eval Rwd Mean: 24.80 | Eval Rwd Var: 335.36
# Episode 13/250 | Ep. Total Reward: 13 | Epsilon : 0.284 | Eval Rwd Mean: 15.20 | Eval Rwd Var: 8.56
# Episode 14/250 | Ep. Total Reward: 16 | Epsilon : 0.262 | Eval Rwd Mean: 16.00 | Eval Rwd Var: 82.00
# Episode 15/250 | Ep. Total Reward: 39 | Epsilon : 0.216 | Eval Rwd Mean: 27.40 | Eval Rwd Var: 801.44
# Episode 16/250 | Ep. Total Reward: 13 | Epsilon : 0.202 | Eval Rwd Mean: 31.00 | Eval Rwd Var: 1128.40
# Episode 17/250 | Ep. Total Reward: 14 | Epsilon : 0.188 | Eval Rwd Mean: 36.80 | Eval Rwd Var: 773.36
# Episode 18/250 | Ep. Total Reward: 14 | Epsilon : 0.176 | Eval Rwd Mean: 19.40 | Eval Rwd Var: 78.64
# Episode 19/250 | Ep. Total Reward: 28 | Epsilon : 0.153 | Eval Rwd Mean: 15.00 | Eval Rwd Var: 9.60
# Episode 20/250 | Ep. Total Reward: 15 | Epsilon : 0.142 | Eval Rwd Mean: 27.00 | Eval Rwd Var: 729.20
# Episode 21/250 | Ep. Total Reward: 15 | Epsilon : 0.131 | Eval Rwd Mean: 17.20 | Eval Rwd Var: 42.56
# Episode 22/250 | Ep. Total Reward: 14 | Epsilon : 0.122 | Eval Rwd Mean: 37.60 | Eval Rwd Var: 1148.24
# Episode 23/250 | Ep. Total Reward: 96 | Epsilon : 0.076 | Eval Rwd Mean: 38.60 | Eval Rwd Var: 239.44
# Episode 24/250 | Ep. Total Reward: 14 | Epsilon : 0.071 | Eval Rwd Mean: 50.40 | Eval Rwd Var: 781.84
# Episode 25/250 | Ep. Total Reward: 12 | Epsilon : 0.066 | Eval Rwd Mean: 25.40 | Eval Rwd Var: 591.84
# Episode 26/250 | Ep. Total Reward: 16 | Epsilon : 0.061 | Eval Rwd Mean: 43.60 | Eval Rwd Var: 1539.84
# Episode 27/250 | Ep. Total Reward: 12 | Epsilon : 0.058 | Eval Rwd Mean: 14.40 | Eval Rwd Var: 2.24
# Episode 28/250 | Ep. Total Reward: 49 | Epsilon : 0.045 | Eval Rwd Mean: 32.00 | Eval Rwd Var: 1334.00
# Episode 29/250 | Ep. Total Reward: 26 | Epsilon : 0.040 | Eval Rwd Mean: 28.40 | Eval Rwd Var: 140.24
# Episode 30/250 | Ep. Total Reward: 27 | Epsilon : 0.035 | Eval Rwd Mean: 29.20 | Eval Rwd Var: 120.96
# Episode 31/250 | Ep. Total Reward: 34 | Epsilon : 0.029 | Eval Rwd Mean: 41.20 | Eval Rwd Var: 752.56
# Episode 32/250 | Ep. Total Reward: 76 | Epsilon : 0.020 | Eval Rwd Mean: 43.40 | Eval Rwd Var: 2039.04
# Episode 33/250 | Ep. Total Reward: 15 | Epsilon : 0.019 | Eval Rwd Mean: 32.20 | Eval Rwd Var: 1632.56
# Episode 34/250 | Ep. Total Reward: 81 | Epsilon : 0.012 | Eval Rwd Mean: 22.00 | Eval Rwd Var: 134.00
# Episode 35/250 | Ep. Total Reward: 42 | Epsilon : 0.010 | Eval Rwd Mean: 31.20 | Eval Rwd Var: 854.96
# Episode 36/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 13.40 | Eval Rwd Var: 3.04
# Episode 37/250 | Ep. Total Reward: 32 | Epsilon : 0.010 | Eval Rwd Mean: 57.40 | Eval Rwd Var: 1376.24
# Episode 38/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 55.40 | Eval Rwd Var: 1938.64
# Episode 39/250 | Ep. Total Reward: 95 | Epsilon : 0.010 | Eval Rwd Mean: 29.40 | Eval Rwd Var: 888.64
# Episode 40/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 19.00 | Eval Rwd Var: 95.20
# Episode 41/250 | Ep. Total Reward: 10 | Epsilon : 0.010 | Eval Rwd Mean: 13.80 | Eval Rwd Var: 4.16
# Episode 42/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 28.80 | Eval Rwd Var: 416.56
# Episode 43/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 52.60 | Eval Rwd Var: 863.44
# Episode 44/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 40.20 | Eval Rwd Var: 422.56
# Episode 45/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 20.20 | Eval Rwd Var: 133.76
# Episode 46/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 34.00 | Eval Rwd Var: 746.80
# Episode 47/250 | Ep. Total Reward: 39 | Epsilon : 0.010 | Eval Rwd Mean: 38.00 | Eval Rwd Var: 1075.60
# Episode 48/250 | Ep. Total Reward: 114 | Epsilon : 0.010 | Eval Rwd Mean: 14.60 | Eval Rwd Var: 0.64
# Episode 49/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 17.40 | Eval Rwd Var: 87.04
# Episode 50/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 34.60 | Eval Rwd Var: 1243.84
# Episode 51/250 | Ep. Total Reward: 44 | Epsilon : 0.010 | Eval Rwd Mean: 66.20 | Eval Rwd Var: 1153.36
# Episode 52/250 | Ep. Total Reward: 101 | Epsilon : 0.010 | Eval Rwd Mean: 35.20 | Eval Rwd Var: 165.76
# Episode 53/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 25.20 | Eval Rwd Var: 69.76
# Episode 54/250 | Ep. Total Reward: 105 | Epsilon : 0.010 | Eval Rwd Mean: 14.40 | Eval Rwd Var: 9.04
# Episode 55/250 | Ep. Total Reward: 87 | Epsilon : 0.010 | Eval Rwd Mean: 38.40 | Eval Rwd Var: 960.24
# Episode 56/250 | Ep. Total Reward: 38 | Epsilon : 0.010 | Eval Rwd Mean: 76.60 | Eval Rwd Var: 1328.64
# Episode 57/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 24.00 | Eval Rwd Var: 444.80
# Episode 58/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 38.40 | Eval Rwd Var: 1040.24
# Episode 59/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 817.04
# Episode 60/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 66.40 | Eval Rwd Var: 2330.64
# Episode 61/250 | Ep. Total Reward: 44 | Epsilon : 0.010 | Eval Rwd Mean: 49.00 | Eval Rwd Var: 2164.40
# Episode 62/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 26.20 | Eval Rwd Var: 477.76
# Episode 63/250 | Ep. Total Reward: 52 | Epsilon : 0.010 | Eval Rwd Mean: 29.20 | Eval Rwd Var: 458.96
# Episode 64/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 38.20 | Eval Rwd Var: 1830.56
# Episode 65/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 49.00 | Eval Rwd Var: 952.00
# Episode 66/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 19.20 | Eval Rwd Var: 119.76
# Episode 67/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 36.80 | Eval Rwd Var: 2266.56
# Episode 68/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 50.40 | Eval Rwd Var: 1037.84
# Episode 69/250 | Ep. Total Reward: 119 | Epsilon : 0.010 | Eval Rwd Mean: 40.40 | Eval Rwd Var: 759.44
# Episode 70/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 13.00 | Eval Rwd Var: 1.60
# Episode 71/250 | Ep. Total Reward: 129 | Epsilon : 0.010 | Eval Rwd Mean: 42.20 | Eval Rwd Var: 1263.36
# Episode 72/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 46.60 | Eval Rwd Var: 2579.84
# Episode 73/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 25.80 | Eval Rwd Var: 316.16
# Episode 74/250 | Ep. Total Reward: 94 | Epsilon : 0.010 | Eval Rwd Mean: 45.80 | Eval Rwd Var: 1553.76
# Episode 75/250 | Ep. Total Reward: 102 | Epsilon : 0.010 | Eval Rwd Mean: 30.80 | Eval Rwd Var: 511.76
# Episode 76/250 | Ep. Total Reward: 34 | Epsilon : 0.010 | Eval Rwd Mean: 36.00 | Eval Rwd Var: 192.00
# Episode 77/250 | Ep. Total Reward: 47 | Epsilon : 0.010 | Eval Rwd Mean: 22.40 | Eval Rwd Var: 169.84
# Episode 78/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 17.60 | Eval Rwd Var: 69.04
# Episode 79/250 | Ep. Total Reward: 112 | Epsilon : 0.010 | Eval Rwd Mean: 13.40 | Eval Rwd Var: 2.64
# Episode 80/250 | Ep. Total Reward: 47 | Epsilon : 0.010 | Eval Rwd Mean: 43.20 | Eval Rwd Var: 1440.56
# Episode 81/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 50.60 | Eval Rwd Var: 1412.64
# Episode 82/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 38.20 | Eval Rwd Var: 2745.76
# Episode 83/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 31.20 | Eval Rwd Var: 516.56
# Episode 84/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 722.64
# Episode 85/250 | Ep. Total Reward: 24 | Epsilon : 0.010 | Eval Rwd Mean: 32.00 | Eval Rwd Var: 1561.60
# Episode 86/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 25.80 | Eval Rwd Var: 314.56
# Episode 87/250 | Ep. Total Reward: 95 | Epsilon : 0.010 | Eval Rwd Mean: 46.20 | Eval Rwd Var: 1776.16
# Episode 88/250 | Ep. Total Reward: 20 | Epsilon : 0.010 | Eval Rwd Mean: 35.80 | Eval Rwd Var: 893.76
# Episode 89/250 | Ep. Total Reward: 52 | Epsilon : 0.010 | Eval Rwd Mean: 56.00 | Eval Rwd Var: 1991.60
# Episode 90/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 44.20 | Eval Rwd Var: 2023.76
# Episode 91/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 33.20 | Eval Rwd Var: 915.76
# Episode 92/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 18.40 | Eval Rwd Var: 22.64
# Episode 93/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 26.00 | Eval Rwd Var: 236.40
# Episode 94/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 33.00 | Eval Rwd Var: 1208.80
# Episode 95/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 565.84
# Episode 96/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 18.60 | Eval Rwd Var: 139.44
# Episode 97/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 36.80 | Eval Rwd Var: 1424.56
# Episode 98/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 32.80 | Eval Rwd Var: 852.56
# Episode 99/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 34.80 | Eval Rwd Var: 1217.36
# Episode 100/250 | Ep. Total Reward: 77 | Epsilon : 0.010 | Eval Rwd Mean: 47.60 | Eval Rwd Var: 1161.04
# Episode 101/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 41.40 | Eval Rwd Var: 696.64
# Episode 102/250 | Ep. Total Reward: 141 | Epsilon : 0.010 | Eval Rwd Mean: 37.40 | Eval Rwd Var: 635.04
# Episode 103/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 50.60 | Eval Rwd Var: 1004.24
# Episode 104/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 16.40 | Eval Rwd Var: 53.84
# Episode 105/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 29.40 | Eval Rwd Var: 288.64
# Episode 106/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 26.20 | Eval Rwd Var: 114.56
# Episode 107/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 60.20 | Eval Rwd Var: 2364.16
# Episode 108/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 41.40 | Eval Rwd Var: 1549.84
# Episode 109/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 22.00 | Eval Rwd Var: 92.80
# Episode 110/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 36.80 | Eval Rwd Var: 1288.96
# Episode 111/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 30.40 | Eval Rwd Var: 729.84
# Episode 112/250 | Ep. Total Reward: 26 | Epsilon : 0.010 | Eval Rwd Mean: 25.80 | Eval Rwd Var: 262.96
# Episode 113/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 28.80 | Eval Rwd Var: 99.76
# Episode 114/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 33.00 | Eval Rwd Var: 612.40
# Episode 115/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 21.20 | Eval Rwd Var: 93.36
# Episode 116/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 42.40 | Eval Rwd Var: 957.04
# Episode 117/250 | Ep. Total Reward: 32 | Epsilon : 0.010 | Eval Rwd Mean: 20.00 | Eval Rwd Var: 274.00
# Episode 118/250 | Ep. Total Reward: 83 | Epsilon : 0.010 | Eval Rwd Mean: 35.60 | Eval Rwd Var: 446.24
# Episode 119/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 23.60 | Eval Rwd Var: 106.24
# Episode 120/250 | Ep. Total Reward: 18 | Epsilon : 0.010 | Eval Rwd Mean: 45.20 | Eval Rwd Var: 1762.96
# Episode 121/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 74.00 | Eval Rwd Var: 1191.20
# Episode 122/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 766.64
# Episode 123/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 57.20 | Eval Rwd Var: 1616.16
# Episode 124/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 36.00 | Eval Rwd Var: 2163.60
# Episode 125/250 | Ep. Total Reward: 21 | Epsilon : 0.010 | Eval Rwd Mean: 40.00 | Eval Rwd Var: 806.00
# Episode 126/250 | Ep. Total Reward: 85 | Epsilon : 0.010 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 2.96
# Episode 127/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 28.60 | Eval Rwd Var: 1005.44
# Episode 128/250 | Ep. Total Reward: 90 | Epsilon : 0.010 | Eval Rwd Mean: 30.40 | Eval Rwd Var: 1282.64
# Episode 129/250 | Ep. Total Reward: 69 | Epsilon : 0.010 | Eval Rwd Mean: 47.80 | Eval Rwd Var: 3377.76
# Episode 130/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 34.20 | Eval Rwd Var: 984.16
# Episode 131/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 26.20 | Eval Rwd Var: 596.96
# Episode 132/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 47.00 | Eval Rwd Var: 2052.80
# Episode 133/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 18.60 | Eval Rwd Var: 149.84
# Episode 134/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 24.20 | Eval Rwd Var: 192.96
# Episode 135/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 22.80 | Eval Rwd Var: 119.76
# Episode 136/250 | Ep. Total Reward: 89 | Epsilon : 0.010 | Eval Rwd Mean: 13.00 | Eval Rwd Var: 1.60
# Episode 137/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 15.20 | Eval Rwd Var: 24.56
# Episode 138/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 20.80 | Eval Rwd Var: 148.56
# Episode 139/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 23.20 | Eval Rwd Var: 134.96
# Episode 140/250 | Ep. Total Reward: 55 | Epsilon : 0.010 | Eval Rwd Mean: 60.40 | Eval Rwd Var: 1685.44
# Episode 141/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 37.00 | Eval Rwd Var: 2210.00
# Episode 142/250 | Ep. Total Reward: 103 | Epsilon : 0.010 | Eval Rwd Mean: 27.60 | Eval Rwd Var: 882.64
# Episode 143/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 23.40 | Eval Rwd Var: 412.64
# Episode 144/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 37.40 | Eval Rwd Var: 945.04
# Episode 145/250 | Ep. Total Reward: 115 | Epsilon : 0.010 | Eval Rwd Mean: 58.20 | Eval Rwd Var: 974.96
# Episode 146/250 | Ep. Total Reward: 10 | Epsilon : 0.010 | Eval Rwd Mean: 27.20 | Eval Rwd Var: 138.96
# Episode 147/250 | Ep. Total Reward: 139 | Epsilon : 0.010 | Eval Rwd Mean: 38.80 | Eval Rwd Var: 484.56
# Episode 148/250 | Ep. Total Reward: 78 | Epsilon : 0.010 | Eval Rwd Mean: 17.00 | Eval Rwd Var: 90.40
# Episode 149/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 27.00 | Eval Rwd Var: 132.80
# Episode 150/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 27.80 | Eval Rwd Var: 876.96
# Episode 151/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 35.60 | Eval Rwd Var: 829.04
# Episode 152/250 | Ep. Total Reward: 90 | Epsilon : 0.010 | Eval Rwd Mean: 30.60 | Eval Rwd Var: 395.84
# Episode 153/250 | Ep. Total Reward: 28 | Epsilon : 0.010 | Eval Rwd Mean: 44.60 | Eval Rwd Var: 1087.04
# Episode 154/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 23.20 | Eval Rwd Var: 437.36
# Episode 155/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 17.40 | Eval Rwd Var: 37.84
# Episode 156/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 39.80 | Eval Rwd Var: 599.36
# Episode 157/250 | Ep. Total Reward: 35 | Epsilon : 0.010 | Eval Rwd Mean: 23.40 | Eval Rwd Var: 433.44
# Episode 158/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 62.40 | Eval Rwd Var: 1651.04
# Episode 159/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 36.40 | Eval Rwd Var: 600.64
# Episode 160/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 30.40 | Eval Rwd Var: 85.04
# Episode 161/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 28.60 | Eval Rwd Var: 797.04
# Episode 162/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 15.40 | Eval Rwd Var: 29.44
# Episode 163/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 31.40 | Eval Rwd Var: 1050.24
# Episode 164/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 38.00 | Eval Rwd Var: 1521.60
# Episode 165/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 29.60 | Eval Rwd Var: 557.44
# Episode 166/250 | Ep. Total Reward: 44 | Epsilon : 0.010 | Eval Rwd Mean: 24.40 | Eval Rwd Var: 164.24
# Episode 167/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 22.60 | Eval Rwd Var: 279.04
# Episode 168/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 15.40 | Eval Rwd Var: 23.84
# Episode 169/250 | Ep. Total Reward: 95 | Epsilon : 0.010 | Eval Rwd Mean: 68.00 | Eval Rwd Var: 2203.20
# Episode 170/250 | Ep. Total Reward: 89 | Epsilon : 0.010 | Eval Rwd Mean: 50.00 | Eval Rwd Var: 1431.60
# Episode 171/250 | Ep. Total Reward: 122 | Epsilon : 0.010 | Eval Rwd Mean: 52.00 | Eval Rwd Var: 1161.20
# Episode 172/250 | Ep. Total Reward: 48 | Epsilon : 0.010 | Eval Rwd Mean: 30.40 | Eval Rwd Var: 647.44
# Episode 173/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 35.00 | Eval Rwd Var: 996.80
# Episode 174/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 22.80 | Eval Rwd Var: 138.56
# Episode 175/250 | Ep. Total Reward: 52 | Epsilon : 0.010 | Eval Rwd Mean: 47.40 | Eval Rwd Var: 1390.64
# Episode 176/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 41.40 | Eval Rwd Var: 1016.64
# Episode 177/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 28.40 | Eval Rwd Var: 860.24
# Episode 178/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 69.20 | Eval Rwd Var: 2014.96
# Episode 179/250 | Ep. Total Reward: 62 | Epsilon : 0.010 | Eval Rwd Mean: 25.20 | Eval Rwd Var: 571.76
# Episode 180/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 32.40 | Eval Rwd Var: 767.44
# Episode 181/250 | Ep. Total Reward: 38 | Epsilon : 0.010 | Eval Rwd Mean: 27.80 | Eval Rwd Var: 410.16
# Episode 182/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 53.60 | Eval Rwd Var: 1830.64
# Episode 183/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 38.20 | Eval Rwd Var: 712.16
# Episode 184/250 | Ep. Total Reward: 42 | Epsilon : 0.010 | Eval Rwd Mean: 51.80 | Eval Rwd Var: 2292.56
# Episode 185/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 29.60 | Eval Rwd Var: 632.24
# Episode 186/250 | Ep. Total Reward: 32 | Epsilon : 0.010 | Eval Rwd Mean: 20.60 | Eval Rwd Var: 112.64
# Episode 187/250 | Ep. Total Reward: 116 | Epsilon : 0.010 | Eval Rwd Mean: 19.80 | Eval Rwd Var: 199.36
# Episode 188/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 45.40 | Eval Rwd Var: 1251.84
# Episode 189/250 | Ep. Total Reward: 34 | Epsilon : 0.010 | Eval Rwd Mean: 52.80 | Eval Rwd Var: 2558.16
# Episode 190/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 45.60 | Eval Rwd Var: 1629.84
# Episode 191/250 | Ep. Total Reward: 48 | Epsilon : 0.010 | Eval Rwd Mean: 14.40 | Eval Rwd Var: 12.24
# Episode 192/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 18.80 | Eval Rwd Var: 49.36
# Episode 193/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 28.80 | Eval Rwd Var: 458.56
# Episode 194/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 18.00 | Eval Rwd Var: 102.40
# Episode 195/250 | Ep. Total Reward: 87 | Epsilon : 0.010 | Eval Rwd Mean: 35.20 | Eval Rwd Var: 518.96
# Episode 196/250 | Ep. Total Reward: 42 | Epsilon : 0.010 | Eval Rwd Mean: 19.40 | Eval Rwd Var: 181.44
# Episode 197/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 23.60 | Eval Rwd Var: 269.84
# Episode 198/250 | Ep. Total Reward: 87 | Epsilon : 0.010 | Eval Rwd Mean: 39.40 | Eval Rwd Var: 1189.84
# Episode 199/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 38.00 | Eval Rwd Var: 1157.20
# Episode 200/250 | Ep. Total Reward: 91 | Epsilon : 0.010 | Eval Rwd Mean: 15.60 | Eval Rwd Var: 33.84
# Episode 201/250 | Ep. Total Reward: 10 | Epsilon : 0.010 | Eval Rwd Mean: 28.20 | Eval Rwd Var: 242.96
# Episode 202/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 850.64
# Episode 203/250 | Ep. Total Reward: 38 | Epsilon : 0.010 | Eval Rwd Mean: 34.40 | Eval Rwd Var: 503.44
# Episode 204/250 | Ep. Total Reward: 77 | Epsilon : 0.010 | Eval Rwd Mean: 54.20 | Eval Rwd Var: 1653.76
# Episode 205/250 | Ep. Total Reward: 91 | Epsilon : 0.010 | Eval Rwd Mean: 73.40 | Eval Rwd Var: 1158.64
# Episode 206/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 37.80 | Eval Rwd Var: 832.96
# Episode 207/250 | Ep. Total Reward: 36 | Epsilon : 0.010 | Eval Rwd Mean: 39.80 | Eval Rwd Var: 1136.16
# Episode 208/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 13.60 | Eval Rwd Var: 1.04
# Episode 209/250 | Ep. Total Reward: 23 | Epsilon : 0.010 | Eval Rwd Mean: 32.40 | Eval Rwd Var: 714.24
# Episode 210/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 29.80 | Eval Rwd Var: 558.96
# Episode 211/250 | Ep. Total Reward: 40 | Epsilon : 0.010 | Eval Rwd Mean: 33.60 | Eval Rwd Var: 571.84
# Episode 212/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 51.20 | Eval Rwd Var: 1724.56
# Episode 213/250 | Ep. Total Reward: 38 | Epsilon : 0.010 | Eval Rwd Mean: 21.40 | Eval Rwd Var: 92.64
# Episode 214/250 | Ep. Total Reward: 81 | Epsilon : 0.010 | Eval Rwd Mean: 15.60 | Eval Rwd Var: 14.64
# Episode 215/250 | Ep. Total Reward: 79 | Epsilon : 0.010 | Eval Rwd Mean: 48.60 | Eval Rwd Var: 1760.24
# Episode 216/250 | Ep. Total Reward: 136 | Epsilon : 0.010 | Eval Rwd Mean: 17.00 | Eval Rwd Var: 16.80
# Episode 217/250 | Ep. Total Reward: 84 | Epsilon : 0.010 | Eval Rwd Mean: 35.40 | Eval Rwd Var: 1311.04
# Episode 218/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 34.00 | Eval Rwd Var: 466.80
# Episode 219/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 42.00 | Eval Rwd Var: 1214.00
# Episode 220/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 25.40 | Eval Rwd Var: 719.04
# Episode 221/250 | Ep. Total Reward: 42 | Epsilon : 0.010 | Eval Rwd Mean: 27.00 | Eval Rwd Var: 841.60
# Episode 222/250 | Ep. Total Reward: 44 | Epsilon : 0.010 | Eval Rwd Mean: 19.20 | Eval Rwd Var: 182.16
# Episode 223/250 | Ep. Total Reward: 75 | Epsilon : 0.010 | Eval Rwd Mean: 25.40 | Eval Rwd Var: 120.64
# Episode 224/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 28.20 | Eval Rwd Var: 456.16
# Episode 225/250 | Ep. Total Reward: 72 | Epsilon : 0.010 | Eval Rwd Mean: 21.40 | Eval Rwd Var: 126.64
# Episode 226/250 | Ep. Total Reward: 10 | Epsilon : 0.010 | Eval Rwd Mean: 35.20 | Eval Rwd Var: 1234.96
# Episode 227/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 15.00 | Eval Rwd Var: 20.80
# Episode 228/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 31.60 | Eval Rwd Var: 542.24
# Episode 229/250 | Ep. Total Reward: 143 | Epsilon : 0.010 | Eval Rwd Mean: 26.40 | Eval Rwd Var: 553.84
# Episode 230/250 | Ep. Total Reward: 129 | Epsilon : 0.010 | Eval Rwd Mean: 48.20 | Eval Rwd Var: 1656.16
# Episode 231/250 | Ep. Total Reward: 58 | Epsilon : 0.010 | Eval Rwd Mean: 16.80 | Eval Rwd Var: 74.96
# Episode 232/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 44.20 | Eval Rwd Var: 1339.76
# Episode 233/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 26.20 | Eval Rwd Var: 142.16
# Episode 234/250 | Ep. Total Reward: 13 | Epsilon : 0.010 | Eval Rwd Mean: 25.80 | Eval Rwd Var: 125.76
# Episode 235/250 | Ep. Total Reward: 80 | Epsilon : 0.010 | Eval Rwd Mean: 39.00 | Eval Rwd Var: 864.40
# Episode 236/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 18.80 | Eval Rwd Var: 53.36
# Episode 237/250 | Ep. Total Reward: 25 | Epsilon : 0.010 | Eval Rwd Mean: 16.60 | Eval Rwd Var: 59.84
# Episode 238/250 | Ep. Total Reward: 15 | Epsilon : 0.010 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 0.96
# Episode 239/250 | Ep. Total Reward: 76 | Epsilon : 0.010 | Eval Rwd Mean: 61.00 | Eval Rwd Var: 2031.20
# Episode 240/250 | Ep. Total Reward: 81 | Epsilon : 0.010 | Eval Rwd Mean: 62.60 | Eval Rwd Var: 1836.64
# Episode 241/250 | Ep. Total Reward: 16 | Epsilon : 0.010 | Eval Rwd Mean: 27.60 | Eval Rwd Var: 235.84
# Episode 242/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 42.40 | Eval Rwd Var: 2399.44
# Episode 243/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 59.20 | Eval Rwd Var: 2766.16
# Episode 244/250 | Ep. Total Reward: 11 | Epsilon : 0.010 | Eval Rwd Mean: 12.60 | Eval Rwd Var: 1.84
# Episode 245/250 | Ep. Total Reward: 54 | Epsilon : 0.010 | Eval Rwd Mean: 50.80 | Eval Rwd Var: 1774.16
# Episode 246/250 | Ep. Total Reward: 12 | Epsilon : 0.010 | Eval Rwd Mean: 35.40 | Eval Rwd Var: 1670.64
# Episode 247/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 35.60 | Eval Rwd Var: 964.24
# Episode 248/250 | Ep. Total Reward: 14 | Epsilon : 0.010 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 0.96
# Episode 249/250 | Ep. Total Reward: 95 | Epsilon : 0.010 | Eval Rwd Mean: 23.80 | Eval Rwd Var: 154.16
# Episode 250/250 | Ep. Total Reward: 101 | Epsilon : 0.010 | Eval Rwd Mean: 32.40 | Eval Rwd Var: 1052.24
#
# Training time: 0.0010 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
## Plot Results
plot_smoothed_training_rwd(train_reward_lst, window_size=20)
plot_eval_rwd_mean(eval_reward_mean_lst)
plot_eval_rwd_var(eval_reward_var_lst)

# %% [markdown]
# # Q-Network - Alternative

# %%
# Q-Network - Alternative
## Hyperparameters for Q-Network-Alternative
lr_alt = 0.001
epoch_alt = 1
episodes_alt = 500
epsilon_alt = 1.0
epsilon_min_alt = 0.01
epsilon_decay_alt = 0.998
gamma_alt = 0.99
hidden_units1_alt = 128
hidden_units2_alt = 128

## Model Construction
# Environment initialization
env_alt = gym.make("CartPole-v1")
state_size_alt = env_alt.observation_space.shape[0]
action_size_alt = env_alt.action_space.n

# Define base Q-Network
model_alt = Sequential()
model_alt.add(Dense(
    hidden_units1_alt,
    input_dim=state_size_alt,
    activation='leaky_relu',
    kernel_initializer='he_uniform'
))
model_alt.add(Dense(
    hidden_units2_alt,
    activation='leaky_relu',
    kernel_initializer='he_uniform'
))
model_alt.add(Dense(action_size_alt, activation='linear'))

# Compile model
model_alt.compile(optimizer=Adam(learning_rate=lr_alt), loss='mean_squared_error')
model_alt.summary()

## Training Loop (Pure base Q-Network, no target network/replay buffer)
train_rewards_alt = []
eval_means_alt = []
eval_vars_alt = []
total_training_time_alt = 0
current_epsilon = epsilon_alt

for ep in range(episodes_alt):
    state, _ = env_alt.reset()
    state = np.reshape(state, [1, state_size_alt])
    episode_reward_alt = 0
    start_time = time.time()

    for step in range(500):
        # Epsilon-greedy action selection
        if np.random.rand() <= current_epsilon:
            action = np.random.choice(action_size_alt)
        else:
            q_values_alt = model_alt.predict(state, verbose=0)
            action = np.argmax(q_values_alt[0])

        # Execute action and get feedback
        next_state, reward, terminated, truncated, _ = env_alt.step(action)
        next_state = np.reshape(next_state, [1, state_size_alt])
        done = terminated or truncated

        # Base Q-Learning update
        current_q_alt = model_alt.predict(state, verbose=0)
        if done:
            target_q_alt = reward
        else:
            next_q_alt = model_alt.predict(next_state, verbose=0)
            target_q_alt = reward + gamma_alt * np.max(next_q_alt)
        current_q_alt[0][action] = target_q_alt

        # Single-step training
        model_alt.fit(state, current_q_alt, epochs=epoch_alt, verbose=0)

        # Epsilon decay
        if current_epsilon > epsilon_min_alt:
            current_epsilon *= epsilon_decay_alt

        # State update and reward accumulation
        state = next_state
        episode_reward_alt += reward
        if done:
            break

    # Record training time
    end_time = time.time()
    total_training_time_alt += (end_time - start_time)

    # Evaluate current model
    eval_mean_alt, eval_var_alt = evaluation(model_alt)

    # Print log
    print(f"Q-Net-Alt Episode {ep + 1}/{episodes_alt} | "
          f"Training Reward: {episode_reward_alt:.0f} | "
          f"Epsilon: {current_epsilon:.3f} | "
          f"Eval Mean: {eval_mean_alt:.2f} | "
          f"Eval Var: {eval_var_alt:.2f}")

    # Store log data
    train_rewards_alt.append(episode_reward_alt)
    eval_means_alt.append(eval_mean_alt)
    eval_vars_alt.append(eval_var_alt)

    # Early stopping
    if eval_mean_alt >= 500:
        print(f"\nEarly Stopping Triggered! Converged at Episode {ep + 1}")
        break

# Calculate average training time
avg_train_time_alt = total_training_time_alt / (ep + 1)
print(f"\nAverage Training Time per Episode Q-Net-Alt: {avg_train_time_alt:.4f} seconds")

# Environment cleanup
env_alt.close()

# Plot results
plot_smoothed_training_rwd(train_rewards_alt, window_size=20)
plot_eval_rwd_mean(eval_means_alt)
plot_eval_rwd_var(eval_vars_alt)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 128)               640
#
#  dense_49 (Dense)            (None, 128)               16512
#
#  dense_50 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 17410 (68.01 KB)
# Trainable params: 17410 (68.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2025-11-11 11:37:05.966937: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# Q-Net-Alt Episode 1/500 | Training Reward: 21 | Epsilon: 0.959 | Eval Mean: 9.80 | Eval Var: 0.96
# Q-Net-Alt Episode 2/500 | Training Reward: 41 | Epsilon: 0.883 | Eval Mean: 10.00 | Eval Var: 0.80
# Q-Net-Alt Episode 3/500 | Training Reward: 17 | Epsilon: 0.854 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 4/500 | Training Reward: 9 | Epsilon: 0.838 | Eval Mean: 9.00 | Eval Var: 0.40
# Q-Net-Alt Episode 5/500 | Training Reward: 38 | Epsilon: 0.777 | Eval Mean: 9.80 | Eval Var: 0.56
# Q-Net-Alt Episode 6/500 | Training Reward: 13 | Epsilon: 0.757 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 7/500 | Training Reward: 14 | Epsilon: 0.736 | Eval Mean: 8.80 | Eval Var: 0.16
# Q-Net-Alt Episode 8/500 | Training Reward: 19 | Epsilon: 0.709 | Eval Mean: 9.20 | Eval Var: 0.16
# Q-Net-Alt Episode 9/500 | Training Reward: 16 | Epsilon: 0.686 | Eval Mean: 9.20 | Eval Var: 0.16
# Q-Net-Alt Episode 10/500 | Training Reward: 10 | Epsilon: 0.673 | Eval Mean: 8.40 | Eval Var: 0.24
# Q-Net-Alt Episode 11/500 | Training Reward: 10 | Epsilon: 0.659 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 12/500 | Training Reward: 12 | Epsilon: 0.644 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 13/500 | Training Reward: 15 | Epsilon: 0.625 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 14/500 | Training Reward: 18 | Epsilon: 0.603 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 15/500 | Training Reward: 13 | Epsilon: 0.587 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 16/500 | Training Reward: 10 | Epsilon: 0.575 | Eval Mean: 9.60 | Eval Var: 0.64
# Q-Net-Alt Episode 17/500 | Training Reward: 11 | Epsilon: 0.563 | Eval Mean: 9.20 | Eval Var: 1.36
# Q-Net-Alt Episode 18/500 | Training Reward: 10 | Epsilon: 0.552 | Eval Mean: 9.00 | Eval Var: 0.80
# Q-Net-Alt Episode 19/500 | Training Reward: 16 | Epsilon: 0.534 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 20/500 | Training Reward: 11 | Epsilon: 0.523 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 21/500 | Training Reward: 9 | Epsilon: 0.513 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 22/500 | Training Reward: 9 | Epsilon: 0.504 | Eval Mean: 9.00 | Eval Var: 0.40
# Q-Net-Alt Episode 23/500 | Training Reward: 11 | Epsilon: 0.493 | Eval Mean: 9.20 | Eval Var: 0.96
# Q-Net-Alt Episode 24/500 | Training Reward: 11 | Epsilon: 0.483 | Eval Mean: 9.20 | Eval Var: 0.96
# Q-Net-Alt Episode 25/500 | Training Reward: 12 | Epsilon: 0.471 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 26/500 | Training Reward: 13 | Epsilon: 0.459 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 27/500 | Training Reward: 10 | Epsilon: 0.450 | Eval Mean: 9.00 | Eval Var: 0.40
# Q-Net-Alt Episode 28/500 | Training Reward: 15 | Epsilon: 0.437 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 29/500 | Training Reward: 10 | Epsilon: 0.428 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 30/500 | Training Reward: 16 | Epsilon: 0.414 | Eval Mean: 9.00 | Eval Var: 0.80
# Q-Net-Alt Episode 31/500 | Training Reward: 9 | Epsilon: 0.407 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 32/500 | Training Reward: 11 | Epsilon: 0.398 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 33/500 | Training Reward: 12 | Epsilon: 0.389 | Eval Mean: 8.80 | Eval Var: 0.16
# Q-Net-Alt Episode 34/500 | Training Reward: 9 | Epsilon: 0.382 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 35/500 | Training Reward: 9 | Epsilon: 0.375 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 36/500 | Training Reward: 18 | Epsilon: 0.362 | Eval Mean: 11.20 | Eval Var: 0.96
# Q-Net-Alt Episode 37/500 | Training Reward: 12 | Epsilon: 0.353 | Eval Mean: 10.40 | Eval Var: 0.24
# Q-Net-Alt Episode 38/500 | Training Reward: 9 | Epsilon: 0.347 | Eval Mean: 10.40 | Eval Var: 0.24
# Q-Net-Alt Episode 39/500 | Training Reward: 16 | Epsilon: 0.336 | Eval Mean: 9.60 | Eval Var: 1.04
# Q-Net-Alt Episode 40/500 | Training Reward: 11 | Epsilon: 0.329 | Eval Mean: 9.60 | Eval Var: 0.64
# Q-Net-Alt Episode 41/500 | Training Reward: 16 | Epsilon: 0.318 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 42/500 | Training Reward: 9 | Epsilon: 0.312 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 43/500 | Training Reward: 9 | Epsilon: 0.307 | Eval Mean: 9.80 | Eval Var: 0.96
# Q-Net-Alt Episode 44/500 | Training Reward: 13 | Epsilon: 0.299 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 45/500 | Training Reward: 12 | Epsilon: 0.292 | Eval Mean: 10.20 | Eval Var: 0.56
# Q-Net-Alt Episode 46/500 | Training Reward: 12 | Epsilon: 0.285 | Eval Mean: 11.00 | Eval Var: 0.40
# Q-Net-Alt Episode 47/500 | Training Reward: 13 | Epsilon: 0.278 | Eval Mean: 11.40 | Eval Var: 1.44
# Q-Net-Alt Episode 48/500 | Training Reward: 10 | Epsilon: 0.272 | Eval Mean: 13.00 | Eval Var: 2.00
# Q-Net-Alt Episode 49/500 | Training Reward: 11 | Epsilon: 0.266 | Eval Mean: 12.80 | Eval Var: 3.36
# Q-Net-Alt Episode 50/500 | Training Reward: 16 | Epsilon: 0.258 | Eval Mean: 16.40 | Eval Var: 6.24
# Q-Net-Alt Episode 51/500 | Training Reward: 17 | Epsilon: 0.249 | Eval Mean: 17.40 | Eval Var: 2.24
# Q-Net-Alt Episode 52/500 | Training Reward: 40 | Epsilon: 0.230 | Eval Mean: 28.60 | Eval Var: 3.44
# Q-Net-Alt Episode 53/500 | Training Reward: 38 | Epsilon: 0.213 | Eval Mean: 28.20 | Eval Var: 4.16
# Q-Net-Alt Episode 54/500 | Training Reward: 26 | Epsilon: 0.202 | Eval Mean: 26.20 | Eval Var: 5.76
# Q-Net-Alt Episode 55/500 | Training Reward: 24 | Epsilon: 0.193 | Eval Mean: 27.20 | Eval Var: 3.36
# Q-Net-Alt Episode 56/500 | Training Reward: 60 | Epsilon: 0.171 | Eval Mean: 27.40 | Eval Var: 1.84
# Q-Net-Alt Episode 57/500 | Training Reward: 25 | Epsilon: 0.163 | Eval Mean: 10.40 | Eval Var: 0.24
# Q-Net-Alt Episode 58/500 | Training Reward: 8 | Epsilon: 0.160 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 59/500 | Training Reward: 8 | Epsilon: 0.158 | Eval Mean: 9.00 | Eval Var: 0.00
# Q-Net-Alt Episode 60/500 | Training Reward: 15 | Epsilon: 0.153 | Eval Mean: 9.80 | Eval Var: 0.56
# Q-Net-Alt Episode 61/500 | Training Reward: 10 | Epsilon: 0.150 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 62/500 | Training Reward: 9 | Epsilon: 0.147 | Eval Mean: 8.80 | Eval Var: 0.56
# Q-Net-Alt Episode 63/500 | Training Reward: 13 | Epsilon: 0.143 | Eval Mean: 9.00 | Eval Var: 0.40
# Q-Net-Alt Episode 64/500 | Training Reward: 12 | Epsilon: 0.140 | Eval Mean: 9.20 | Eval Var: 0.96
# Q-Net-Alt Episode 65/500 | Training Reward: 15 | Epsilon: 0.136 | Eval Mean: 26.80 | Eval Var: 170.96
# Q-Net-Alt Episode 66/500 | Training Reward: 12 | Epsilon: 0.133 | Eval Mean: 85.80 | Eval Var: 6963.76
# Q-Net-Alt Episode 67/500 | Training Reward: 11 | Epsilon: 0.130 | Eval Mean: 168.20 | Eval Var: 12310.56
# Q-Net-Alt Episode 68/500 | Training Reward: 56 | Epsilon: 0.116 | Eval Mean: 26.20 | Eval Var: 10.96
# Q-Net-Alt Episode 69/500 | Training Reward: 25 | Epsilon: 0.110 | Eval Mean: 26.40 | Eval Var: 1.44
# Q-Net-Alt Episode 70/500 | Training Reward: 100 | Epsilon: 0.090 | Eval Mean: 26.20 | Eval Var: 6.16
# Q-Net-Alt Episode 71/500 | Training Reward: 212 | Epsilon: 0.059 | Eval Mean: 142.00 | Eval Var: 14.80
# Q-Net-Alt Episode 72/500 | Training Reward: 77 | Epsilon: 0.051 | Eval Mean: 112.60 | Eval Var: 1544.64
# Q-Net-Alt Episode 73/500 | Training Reward: 61 | Epsilon: 0.045 | Eval Mean: 17.00 | Eval Var: 73.60
# Q-Net-Alt Episode 74/500 | Training Reward: 78 | Epsilon: 0.038 | Eval Mean: 123.20 | Eval Var: 1738.96
# Q-Net-Alt Episode 75/500 | Training Reward: 26 | Epsilon: 0.036 | Eval Mean: 23.00 | Eval Var: 31.20
# Q-Net-Alt Episode 76/500 | Training Reward: 12 | Epsilon: 0.036 | Eval Mean: 105.00 | Eval Var: 6741.20
# Q-Net-Alt Episode 77/500 | Training Reward: 11 | Epsilon: 0.035 | Eval Mean: 43.60 | Eval Var: 4251.44
# Q-Net-Alt Episode 78/500 | Training Reward: 10 | Epsilon: 0.034 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 79/500 | Training Reward: 10 | Epsilon: 0.033 | Eval Mean: 10.00 | Eval Var: 0.00
# Q-Net-Alt Episode 80/500 | Training Reward: 10 | Epsilon: 0.033 | Eval Mean: 31.20 | Eval Var: 585.76
# Q-Net-Alt Episode 81/500 | Training Reward: 88 | Epsilon: 0.027 | Eval Mean: 205.60 | Eval Var: 3413.84
# Q-Net-Alt Episode 82/500 | Training Reward: 21 | Epsilon: 0.026 | Eval Mean: 37.40 | Eval Var: 323.84
# Q-Net-Alt Episode 83/500 | Training Reward: 9 | Epsilon: 0.026 | Eval Mean: 8.80 | Eval Var: 0.16
# Q-Net-Alt Episode 84/500 | Training Reward: 9 | Epsilon: 0.025 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 85/500 | Training Reward: 10 | Epsilon: 0.025 | Eval Mean: 10.20 | Eval Var: 0.16
# Q-Net-Alt Episode 86/500 | Training Reward: 10 | Epsilon: 0.024 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 87/500 | Training Reward: 8 | Epsilon: 0.024 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 88/500 | Training Reward: 8 | Epsilon: 0.024 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 89/500 | Training Reward: 10 | Epsilon: 0.023 | Eval Mean: 9.20 | Eval Var: 1.36
# Q-Net-Alt Episode 90/500 | Training Reward: 11 | Epsilon: 0.023 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 91/500 | Training Reward: 9 | Epsilon: 0.022 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 92/500 | Training Reward: 11 | Epsilon: 0.022 | Eval Mean: 8.80 | Eval Var: 0.56
# Q-Net-Alt Episode 93/500 | Training Reward: 10 | Epsilon: 0.021 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 94/500 | Training Reward: 10 | Epsilon: 0.021 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 95/500 | Training Reward: 10 | Epsilon: 0.020 | Eval Mean: 9.20 | Eval Var: 0.56
# Q-Net-Alt Episode 96/500 | Training Reward: 11 | Epsilon: 0.020 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 97/500 | Training Reward: 10 | Epsilon: 0.020 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 98/500 | Training Reward: 9 | Epsilon: 0.019 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 99/500 | Training Reward: 10 | Epsilon: 0.019 | Eval Mean: 9.40 | Eval Var: 0.64
# Q-Net-Alt Episode 100/500 | Training Reward: 8 | Epsilon: 0.019 | Eval Mean: 9.40 | Eval Var: 0.24
# Q-Net-Alt Episode 101/500 | Training Reward: 10 | Epsilon: 0.018 | Eval Mean: 9.60 | Eval Var: 1.04
# Q-Net-Alt Episode 102/500 | Training Reward: 10 | Epsilon: 0.018 | Eval Mean: 9.20 | Eval Var: 0.16
# Q-Net-Alt Episode 103/500 | Training Reward: 10 | Epsilon: 0.018 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 104/500 | Training Reward: 10 | Epsilon: 0.017 | Eval Mean: 10.00 | Eval Var: 0.00
# Q-Net-Alt Episode 105/500 | Training Reward: 10 | Epsilon: 0.017 | Eval Mean: 9.20 | Eval Var: 0.16
# Q-Net-Alt Episode 106/500 | Training Reward: 10 | Epsilon: 0.017 | Eval Mean: 12.60 | Eval Var: 8.24
# Q-Net-Alt Episode 107/500 | Training Reward: 10 | Epsilon: 0.016 | Eval Mean: 27.80 | Eval Var: 458.16
# Q-Net-Alt Episode 108/500 | Training Reward: 41 | Epsilon: 0.015 | Eval Mean: 119.00 | Eval Var: 95.20
# Q-Net-Alt Episode 109/500 | Training Reward: 248 | Epsilon: 0.010 | Eval Mean: 201.00 | Eval Var: 1034.00
# Q-Net-Alt Episode 110/500 | Training Reward: 256 | Epsilon: 0.010 | Eval Mean: 17.60 | Eval Var: 2.64
# Q-Net-Alt Episode 111/500 | Training Reward: 58 | Epsilon: 0.010 | Eval Mean: 101.40 | Eval Var: 464.24
# Q-Net-Alt Episode 112/500 | Training Reward: 55 | Epsilon: 0.010 | Eval Mean: 137.20 | Eval Var: 645.36
# Q-Net-Alt Episode 113/500 | Training Reward: 88 | Epsilon: 0.010 | Eval Mean: 47.20 | Eval Var: 407.76
# Q-Net-Alt Episode 114/500 | Training Reward: 29 | Epsilon: 0.010 | Eval Mean: 15.00 | Eval Var: 1.60
# Q-Net-Alt Episode 115/500 | Training Reward: 13 | Epsilon: 0.010 | Eval Mean: 13.20 | Eval Var: 1.36
# Q-Net-Alt Episode 116/500 | Training Reward: 14 | Epsilon: 0.010 | Eval Mean: 15.80 | Eval Var: 2.96
# Q-Net-Alt Episode 117/500 | Training Reward: 15 | Epsilon: 0.010 | Eval Mean: 13.80 | Eval Var: 0.96
# Q-Net-Alt Episode 118/500 | Training Reward: 13 | Epsilon: 0.010 | Eval Mean: 12.20 | Eval Var: 2.16
# Q-Net-Alt Episode 119/500 | Training Reward: 12 | Epsilon: 0.010 | Eval Mean: 10.40 | Eval Var: 1.04
# Q-Net-Alt Episode 120/500 | Training Reward: 10 | Epsilon: 0.010 | Eval Mean: 10.20 | Eval Var: 0.56
# Q-Net-Alt Episode 121/500 | Training Reward: 9 | Epsilon: 0.010 | Eval Mean: 9.80 | Eval Var: 0.16
# Q-Net-Alt Episode 122/500 | Training Reward: 9 | Epsilon: 0.010 | Eval Mean: 8.80 | Eval Var: 0.56
# Q-Net-Alt Episode 123/500 | Training Reward: 9 | Epsilon: 0.010 | Eval Mean: 9.60 | Eval Var: 0.24
# Q-Net-Alt Episode 124/500 | Training Reward: 10 | Epsilon: 0.010 | Eval Mean: 9.80 | Eval Var: 0.56
# Q-Net-Alt Episode 125/500 | Training Reward: 10 | Epsilon: 0.010 | Eval Mean: 9.00 | Eval Var: 0.80
# Q-Net-Alt Episode 126/500 | Training Reward: 9 | Epsilon: 0.010 | Eval Mean: 9.00 | Eval Var: 0.40
# Q-Net-Alt Episode 127/500 | Training Reward: 9 | Epsilon: 0.010 | Eval Mean: 10.20 | Eval Var: 1.36
# Q-Net-Alt Episode 128/500 | Training Reward: 11 | Epsilon: 0.010 | Eval Mean: 11.60 | Eval Var: 0.24
# Q-Net-Alt Episode 129/500 | Training Reward: 14 | Epsilon: 0.010 | Eval Mean: 19.40 | Eval Var: 7.44
# Q-Net-Alt Episode 130/500 | Training Reward: 24 | Epsilon: 0.010 | Eval Mean: 76.80 | Eval Var: 28.16
# Q-Net-Alt Episode 131/500 | Training Reward: 65 | Epsilon: 0.010 | Eval Mean: 101.80 | Eval Var: 91.76
# Q-Net-Alt Episode 132/500 | Training Reward: 95 | Epsilon: 0.010 | Eval Mean: 52.20 | Eval Var: 5.36
# Q-Net-Alt Episode 133/500 | Training Reward: 58 | Epsilon: 0.010 | Eval Mean: 58.80 | Eval Var: 5.76
# Q-Net-Alt Episode 134/500 | Training Reward: 64 | Epsilon: 0.010 | Eval Mean: 62.20 | Eval Var: 8.96
# Q-Net-Alt Episode 135/500 | Training Reward: 66 | Epsilon: 0.010 | Eval Mean: 66.40 | Eval Var: 19.44
# Q-Net-Alt Episode 136/500 | Training Reward: 60 | Epsilon: 0.010 | Eval Mean: 66.60 | Eval Var: 15.44
# Q-Net-Alt Episode 137/500 | Training Reward: 112 | Epsilon: 0.010 | Eval Mean: 63.20 | Eval Var: 21.76
# Q-Net-Alt Episode 138/500 | Training Reward: 51 | Epsilon: 0.010 | Eval Mean: 54.60 | Eval Var: 12.24
# Q-Net-Alt Episode 139/500 | Training Reward: 46 | Epsilon: 0.010 | Eval Mean: 73.60 | Eval Var: 80.24
# Q-Net-Alt Episode 140/500 | Training Reward: 96 | Epsilon: 0.010 | Eval Mean: 45.40 | Eval Var: 549.44
# Q-Net-Alt Episode 141/500 | Training Reward: 60 | Epsilon: 0.010 | Eval Mean: 81.80 | Eval Var: 457.36
# Q-Net-Alt Episode 142/500 | Training Reward: 50 | Epsilon: 0.010 | Eval Mean: 51.20 | Eval Var: 2.96
# Q-Net-Alt Episode 143/500 | Training Reward: 41 | Epsilon: 0.010 | Eval Mean: 84.40 | Eval Var: 674.64
# Q-Net-Alt Episode 144/500 | Training Reward: 111 | Epsilon: 0.010 | Eval Mean: 58.00 | Eval Var: 106.00
# Q-Net-Alt Episode 145/500 | Training Reward: 21 | Epsilon: 0.010 | Eval Mean: 42.20 | Eval Var: 274.56
# Q-Net-Alt Episode 146/500 | Training Reward: 57 | Epsilon: 0.010 | Eval Mean: 21.60 | Eval Var: 6.24
# Q-Net-Alt Episode 147/500 | Training Reward: 21 | Epsilon: 0.010 | Eval Mean: 18.20 | Eval Var: 1.76
# Q-Net-Alt Episode 148/500 | Training Reward: 16 | Epsilon: 0.010 | Eval Mean: 13.40 | Eval Var: 1.04
# Q-Net-Alt Episode 149/500 | Training Reward: 10 | Epsilon: 0.010 | Eval Mean: 11.00 | Eval Var: 0.40
# Q-Net-Alt Episode 150/500 | Training Reward: 11 | Epsilon: 0.010 | Eval Mean: 13.00 | Eval Var: 0.40
# Q-Net-Alt Episode 151/500 | Training Reward: 12 | Epsilon: 0.010 | Eval Mean: 18.80 | Eval Var: 2.16
# Q-Net-Alt Episode 152/500 | Training Reward: 19 | Epsilon: 0.010 | Eval Mean: 33.60 | Eval Var: 6.64
# Q-Net-Alt Episode 153/500 | Training Reward: 97 | Epsilon: 0.010 | Eval Mean: 102.80 | Eval Var: 22.16
# Q-Net-Alt Episode 154/500 | Training Reward: 116 | Epsilon: 0.010 | Eval Mean: 43.40 | Eval Var: 23.04
# Q-Net-Alt Episode 155/500 | Training Reward: 51 | Epsilon: 0.010 | Eval Mean: 85.00 | Eval Var: 545.20
# Q-Net-Alt Episode 156/500 | Training Reward: 102 | Epsilon: 0.010 | Eval Mean: 80.60 | Eval Var: 107.44
# Q-Net-Alt Episode 157/500 | Training Reward: 117 | Epsilon: 0.010 | Eval Mean: 93.80 | Eval Var: 60.56
# Q-Net-Alt Episode 158/500 | Training Reward: 113 | Epsilon: 0.010 | Eval Mean: 91.20 | Eval Var: 307.76
# Q-Net-Alt Episode 159/500 | Training Reward: 76 | Epsilon: 0.010 | Eval Mean: 54.40 | Eval Var: 89.04
# Q-Net-Alt Episode 160/500 | Training Reward: 31 | Epsilon: 0.010 | Eval Mean: 26.40 | Eval Var: 14.64
# Q-Net-Alt Episode 161/500 | Training Reward: 21 | Epsilon: 0.010 | Eval Mean: 21.60 | Eval Var: 3.04
# Q-Net-Alt Episode 162/500 | Training Reward: 17 | Epsilon: 0.010 | Eval Mean: 18.00 | Eval Var: 2.00
# Q-Net-Alt Episode 163/500 | Training Reward: 21 | Epsilon: 0.010 | Eval Mean: 20.00 | Eval Var: 4.00
# Q-Net-Alt Episode 164/500 | Training Reward: 20 | Epsilon: 0.010 | Eval Mean: 19.60 | Eval Var: 3.44
# Q-Net-Alt Episode 165/500 | Training Reward: 19 | Epsilon: 0.010 | Eval Mean: 24.00 | Eval Var: 7.60
# Q-Net-Alt Episode 166/500 | Training Reward: 20 | Epsilon: 0.010 | Eval Mean: 43.80 | Eval Var: 410.56
# Q-Net-Alt Episode 167/500 | Training Reward: 29 | Epsilon: 0.010 | Eval Mean: 53.80 | Eval Var: 326.16
# Q-Net-Alt Episode 168/500 | Training Reward: 90 | Epsilon: 0.010 | Eval Mean: 42.00 | Eval Var: 61.20
# Q-Net-Alt Episode 169/500 | Training Reward: 45 | Epsilon: 0.010 | Eval Mean: 34.00 | Eval Var: 20.80
# Q-Net-Alt Episode 170/500 | Training Reward: 28 | Epsilon: 0.010 | Eval Mean: 31.40 | Eval Var: 2.64
# Q-Net-Alt Episode 171/500 | Training Reward: 28 | Epsilon: 0.010 | Eval Mean: 34.00 | Eval Var: 2.80
# Q-Net-Alt Episode 172/500 | Training Reward: 38 | Epsilon: 0.010 | Eval Mean: 50.60 | Eval Var: 29.44
# Q-Net-Alt Episode 173/500 | Training Reward: 35 | Epsilon: 0.010 | Eval Mean: 50.80 | Eval Var: 19.76
# Q-Net-Alt Episode 174/500 | Training Reward: 36 | Epsilon: 0.010 | Eval Mean: 33.40 | Eval Var: 24.24
# Q-Net-Alt Episode 175/500 | Training Reward: 38 | Epsilon: 0.010 | Eval Mean: 30.40 | Eval Var: 3.04
# Q-Net-Alt Episode 176/500 | Training Reward: 32 | Epsilon: 0.010 | Eval Mean: 38.40 | Eval Var: 56.24
# Q-Net-Alt Episode 177/500 | Training Reward: 32 | Epsilon: 0.010 | Eval Mean: 35.00 | Eval Var: 43.60
# Q-Net-Alt Episode 178/500 | Training Reward: 35 | Epsilon: 0.010 | Eval Mean: 34.40 | Eval Var: 5.04
# Q-Net-Alt Episode 179/500 | Training Reward: 30 | Epsilon: 0.010 | Eval Mean: 50.00 | Eval Var: 112.80
# Q-Net-Alt Episode 180/500 | Training Reward: 46 | Epsilon: 0.010 | Eval Mean: 68.80 | Eval Var: 178.16
# Q-Net-Alt Episode 181/500 | Training Reward: 42 | Epsilon: 0.010 | Eval Mean: 31.80 | Eval Var: 6.56
# Q-Net-Alt Episode 182/500 | Training Reward: 40 | Epsilon: 0.010 | Eval Mean: 33.60 | Eval Var: 39.84
# Q-Net-Alt Episode 183/500 | Training Reward: 35 | Epsilon: 0.010 | Eval Mean: 31.20 | Eval Var: 12.96
# Q-Net-Alt Episode 184/500 | Training Reward: 23 | Epsilon: 0.010 | Eval Mean: 32.20 | Eval Var: 6.96
# Q-Net-Alt Episode 185/500 | Training Reward: 43 | Epsilon: 0.010 | Eval Mean: 53.40 | Eval Var: 405.04
# Q-Net-Alt Episode 186/500 | Training Reward: 35 | Epsilon: 0.010 | Eval Mean: 38.20 | Eval Var: 56.56
# Q-Net-Alt Episode 187/500 | Training Reward: 38 | Epsilon: 0.010 | Eval Mean: 31.40 | Eval Var: 5.44
# Q-Net-Alt Episode 188/500 | Training Reward: 96 | Epsilon: 0.010 | Eval Mean: 23.60 | Eval Var: 11.84
# Q-Net-Alt Episode 189/500 | Training Reward: 34 | Epsilon: 0.010 | Eval Mean: 35.40 | Eval Var: 6.64
# Q-Net-Alt Episode 190/500 | Training Reward: 37 | Epsilon: 0.010 | Eval Mean: 37.20 | Eval Var: 24.96
# Q-Net-Alt Episode 191/500 | Training Reward: 34 | Epsilon: 0.010 | Eval Mean: 47.40 | Eval Var: 27.84
# Q-Net-Alt Episode 192/500 | Training Reward: 102 | Epsilon: 0.010 | Eval Mean: 41.80 | Eval Var: 98.16
# Q-Net-Alt Episode 193/500 | Training Reward: 38 | Epsilon: 0.010 | Eval Mean: 36.00 | Eval Var: 24.80
# Q-Net-Alt Episode 194/500 | Training Reward: 32 | Epsilon: 0.010 | Eval Mean: 39.20 | Eval Var: 8.96
# Q-Net-Alt Episode 195/500 | Training Reward: 49 | Epsilon: 0.010 | Eval Mean: 57.20 | Eval Var: 155.76
# Q-Net-Alt Episode 196/500 | Training Reward: 50 | Epsilon: 0.010 | Eval Mean: 43.60 | Eval Var: 41.44
# Q-Net-Alt Episode 197/500 | Training Reward: 44 | Epsilon: 0.010 | Eval Mean: 56.00 | Eval Var: 61.20
# Q-Net-Alt Episode 198/500 | Training Reward: 54 | Epsilon: 0.010 | Eval Mean: 56.00 | Eval Var: 23.60
# Q-Net-Alt Episode 199/500 | Training Reward: 57 | Epsilon: 0.010 | Eval Mean: 39.60 | Eval Var: 3.04
# Q-Net-Alt Episode 200/500 | Training Reward: 38 | Epsilon: 0.010 | Eval Mean: 45.80 | Eval Var: 17.36
# Q-Net-Alt Episode 201/500 | Training Reward: 39 | Epsilon: 0.010 | Eval Mean: 37.80 | Eval Var: 12.56
# Q-Net-Alt Episode 202/500 | Training Reward: 35 | Epsilon: 0.010 | Eval Mean: 42.60 | Eval Var: 29.44
# Q-Net-Alt Episode 203/500 | Training Reward: 45 | Epsilon: 0.010 | Eval Mean: 51.40 | Eval Var: 31.44
# Q-Net-Alt Episode 204/500 | Training Reward: 48 | Epsilon: 0.010 | Eval Mean: 62.20 | Eval Var: 13.36
# Q-Net-Alt Episode 205/500 | Training Reward: 87 | Epsilon: 0.010 | Eval Mean: 64.40 | Eval Var: 33.04
# Q-Net-Alt Episode 206/500 | Training Reward: 50 | Epsilon: 0.010 | Eval Mean: 80.40 | Eval Var: 24.24
# Q-Net-Alt Episode 207/500 | Training Reward: 68 | Epsilon: 0.010 | Eval Mean: 63.60 | Eval Var: 6.24
# Q-Net-Alt Episode 208/500 | Training Reward: 53 | Epsilon: 0.010 | Eval Mean: 57.00 | Eval Var: 18.00
# Q-Net-Alt Episode 209/500 | Training Reward: 55 | Epsilon: 0.010 | Eval Mean: 69.20 | Eval Var: 6.16
# Q-Net-Alt Episode 210/500 | Training Reward: 87 | Epsilon: 0.010 | Eval Mean: 36.80 | Eval Var: 87.36
# Q-Net-Alt Episode 211/500 | Training Reward: 109 | Epsilon: 0.010 | Eval Mean: 25.80 | Eval Var: 7.76
# Q-Net-Alt Episode 212/500 | Training Reward: 105 | Epsilon: 0.010 | Eval Mean: 31.80 | Eval Var: 6.16
# Q-Net-Alt Episode 213/500 | Training Reward: 21 | Epsilon: 0.010 | Eval Mean: 28.00 | Eval Var: 24.40
# Q-Net-Alt Episode 214/500 | Training Reward: 72 | Epsilon: 0.010 | Eval Mean: 198.80 | Eval Var: 2319.36
# Q-Net-Alt Episode 215/500 | Training Reward: 81 | Epsilon: 0.010 | Eval Mean: 96.80 | Eval Var: 47.36
# Q-Net-Alt Episode 216/500 | Training Reward: 109 | Epsilon: 0.010 | Eval Mean: 18.40 | Eval Var: 6.24
# Q-Net-Alt Episode 217/500 | Training Reward: 20 | Epsilon: 0.010 | Eval Mean: 15.20 | Eval Var: 3.76
# Q-Net-Alt Episode 218/500 | Training Reward: 15 | Epsilon: 0.010 | Eval Mean: 16.20 | Eval Var: 4.56
# Q-Net-Alt Episode 219/500 | Training Reward: 19 | Epsilon: 0.010 | Eval Mean: 16.40 | Eval Var: 5.04
# Q-Net-Alt Episode 220/500 | Training Reward: 15 | Epsilon: 0.010 | Eval Mean: 23.60 | Eval Var: 6.64
# Q-Net-Alt Episode 221/500 | Training Reward: 22 | Epsilon: 0.010 | Eval Mean: 41.40 | Eval Var: 53.84
# Q-Net-Alt Episode 222/500 | Training Reward: 125 | Epsilon: 0.010 | Eval Mean: 81.80 | Eval Var: 10.16
# Q-Net-Alt Episode 223/500 | Training Reward: 57 | Epsilon: 0.010 | Eval Mean: 141.60 | Eval Var: 5612.24
# Q-Net-Alt Episode 224/500 | Training Reward: 60 | Epsilon: 0.010 | Eval Mean: 182.40 | Eval Var: 5351.84
# Q-Net-Alt Episode 225/500 | Training Reward: 274 | Epsilon: 0.010 | Eval Mean: 83.80 | Eval Var: 218.16
# Q-Net-Alt Episode 226/500 | Training Reward: 191 | Epsilon: 0.010 | Eval Mean: 82.40 | Eval Var: 193.84
# Q-Net-Alt Episode 227/500 | Training Reward: 54 | Epsilon: 0.010 | Eval Mean: 123.60 | Eval Var: 5539.84
# Q-Net-Alt Episode 228/500 | Training Reward: 138 | Epsilon: 0.010 | Eval Mean: 49.80 | Eval Var: 46.56
# Q-Net-Alt Episode 229/500 | Training Reward: 125 | Epsilon: 0.010 | Eval Mean: 66.40 | Eval Var: 72.24
# Q-Net-Alt Episode 230/500 | Training Reward: 100 | Epsilon: 0.010 | Eval Mean: 179.40 | Eval Var: 490.24
# Q-Net-Alt Episode 231/500 | Training Reward: 186 | Epsilon: 0.010 | Eval Mean: 153.80 | Eval Var: 776.96
# Q-Net-Alt Episode 232/500 | Training Reward: 125 | Epsilon: 0.010 | Eval Mean: 156.00 | Eval Var: 364.00
# Q-Net-Alt Episode 233/500 | Training Reward: 115 | Epsilon: 0.010 | Eval Mean: 144.20 | Eval Var: 451.76
# Q-Net-Alt Episode 234/500 | Training Reward: 115 | Epsilon: 0.010 | Eval Mean: 125.40 | Eval Var: 989.84
# Q-Net-Alt Episode 235/500 | Training Reward: 110 | Epsilon: 0.010 | Eval Mean: 175.80 | Eval Var: 823.76
# Q-Net-Alt Episode 236/500 | Training Reward: 154 | Epsilon: 0.010 | Eval Mean: 131.60 | Eval Var: 49.84
# Q-Net-Alt Episode 237/500 | Training Reward: 130 | Epsilon: 0.010 | Eval Mean: 172.20 | Eval Var: 172.56
# Q-Net-Alt Episode 238/500 | Training Reward: 165 | Epsilon: 0.010 | Eval Mean: 121.80 | Eval Var: 19.36
# Q-Net-Alt Episode 239/500 | Training Reward: 165 | Epsilon: 0.010 | Eval Mean: 19.60 | Eval Var: 4.24
# Q-Net-Alt Episode 240/500 | Training Reward: 100 | Epsilon: 0.010 | Eval Mean: 56.20 | Eval Var: 33.36
# Q-Net-Alt Episode 241/500 | Training Reward: 19 | Epsilon: 0.010 | Eval Mean: 17.80 | Eval Var: 4.56
# Q-Net-Alt Episode 242/500 | Training Reward: 97 | Epsilon: 0.010 | Eval Mean: 212.60 | Eval Var: 3197.04
# Q-Net-Alt Episode 243/500 | Training Reward: 96 | Epsilon: 0.010 | Eval Mean: 185.80 | Eval Var: 3262.96
# Q-Net-Alt Episode 244/500 | Training Reward: 80 | Epsilon: 0.010 | Eval Mean: 140.20 | Eval Var: 3284.56
# Q-Net-Alt Episode 245/500 | Training Reward: 145 | Epsilon: 0.010 | Eval Mean: 89.60 | Eval Var: 101.84
# Q-Net-Alt Episode 246/500 | Training Reward: 74 | Epsilon: 0.010 | Eval Mean: 69.20 | Eval Var: 196.56
# Q-Net-Alt Episode 247/500 | Training Reward: 66 | Epsilon: 0.010 | Eval Mean: 66.00 | Eval Var: 50.80
# Q-Net-Alt Episode 248/500 | Training Reward: 78 | Epsilon: 0.010 | Eval Mean: 120.00 | Eval Var: 4186.00
# Q-Net-Alt Episode 249/500 | Training Reward: 63 | Epsilon: 0.010 | Eval Mean: 137.80 | Eval Var: 13998.16
# Q-Net-Alt Episode 250/500 | Training Reward: 77 | Epsilon: 0.010 | Eval Mean: 66.60 | Eval Var: 50.64
# Q-Net-Alt Episode 251/500 | Training Reward: 293 | Epsilon: 0.010 | Eval Mean: 23.60 | Eval Var: 3.44
# Q-Net-Alt Episode 252/500 | Training Reward: 19 | Epsilon: 0.010 | Eval Mean: 21.60 | Eval Var: 9.04
# Q-Net-Alt Episode 253/500 | Training Reward: 30 | Epsilon: 0.010 | Eval Mean: 67.40 | Eval Var: 83.84
# Q-Net-Alt Episode 254/500 | Training Reward: 81 | Epsilon: 0.010 | Eval Mean: 197.00 | Eval Var: 6976.40
# Q-Net-Alt Episode 255/500 | Training Reward: 220 | Epsilon: 0.010 | Eval Mean: 125.20 | Eval Var: 37.36
# Q-Net-Alt Episode 256/500 | Training Reward: 101 | Epsilon: 0.010 | Eval Mean: 100.40 | Eval Var: 93.44
# Q-Net-Alt Episode 257/500 | Training Reward: 79 | Epsilon: 0.010 | Eval Mean: 121.60 | Eval Var: 1659.84
# Q-Net-Alt Episode 258/500 | Training Reward: 202 | Epsilon: 0.010 | Eval Mean: 82.60 | Eval Var: 188.24
# Q-Net-Alt Episode 259/500 | Training Reward: 59 | Epsilon: 0.010 | Eval Mean: 72.60 | Eval Var: 144.24
# Q-Net-Alt Episode 260/500 | Training Reward: 54 | Epsilon: 0.010 | Eval Mean: 99.00 | Eval Var: 340.40
# Q-Net-Alt Episode 261/500 | Training Reward: 63 | Epsilon: 0.010 | Eval Mean: 155.40 | Eval Var: 11823.04
# Q-Net-Alt Episode 262/500 | Training Reward: 161 | Epsilon: 0.010 | Eval Mean: 50.60 | Eval Var: 21.44
# Q-Net-Alt Episode 263/500 | Training Reward: 61 | Epsilon: 0.010 | Eval Mean: 74.40 | Eval Var: 365.04
# Q-Net-Alt Episode 264/500 | Training Reward: 83 | Epsilon: 0.010 | Eval Mean: 111.20 | Eval Var: 1535.36
# Q-Net-Alt Episode 265/500 | Training Reward: 85 | Epsilon: 0.010 | Eval Mean: 130.00 | Eval Var: 4603.20
# Q-Net-Alt Episode 266/500 | Training Reward: 118 | Epsilon: 0.010 | Eval Mean: 168.60 | Eval Var: 2849.04
# Q-Net-Alt Episode 267/500 | Training Reward: 105 | Epsilon: 0.010 | Eval Mean: 49.80 | Eval Var: 39.76
# Q-Net-Alt Episode 268/500 | Training Reward: 85 | Epsilon: 0.010 | Eval Mean: 39.00 | Eval Var: 17.20
# Q-Net-Alt Episode 269/500 | Training Reward: 102 | Epsilon: 0.010 | Eval Mean: 91.60 | Eval Var: 409.04
# Q-Net-Alt Episode 270/500 | Training Reward: 130 | Epsilon: 0.010 | Eval Mean: 102.20 | Eval Var: 702.16
# Q-Net-Alt Episode 271/500 | Training Reward: 118 | Epsilon: 0.010 | Eval Mean: 130.00 | Eval Var: 968.00
# Q-Net-Alt Episode 272/500 | Training Reward: 90 | Epsilon: 0.010 | Eval Mean: 167.40 | Eval Var: 2116.24
# Q-Net-Alt Episode 273/500 | Training Reward: 105 | Epsilon: 0.010 | Eval Mean: 86.80 | Eval Var: 32.56
# Q-Net-Alt Episode 274/500 | Training Reward: 96 | Epsilon: 0.010 | Eval Mean: 174.20 | Eval Var: 9921.36
# Q-Net-Alt Episode 275/500 | Training Reward: 122 | Epsilon: 0.010 | Eval Mean: 212.40 | Eval Var: 3611.04
# Q-Net-Alt Episode 276/500 | Training Reward: 93 | Epsilon: 0.010 | Eval Mean: 75.80 | Eval Var: 88.96
# Q-Net-Alt Episode 277/500 | Training Reward: 81 | Epsilon: 0.010 | Eval Mean: 131.40 | Eval Var: 320.64
# Q-Net-Alt Episode 278/500 | Training Reward: 151 | Epsilon: 0.010 | Eval Mean: 58.20 | Eval Var: 122.56
# Q-Net-Alt Episode 279/500 | Training Reward: 59 | Epsilon: 0.010 | Eval Mean: 110.80 | Eval Var: 254.96
# Q-Net-Alt Episode 280/500 | Training Reward: 108 | Epsilon: 0.010 | Eval Mean: 37.40 | Eval Var: 41.04
# Q-Net-Alt Episode 281/500 | Training Reward: 85 | Epsilon: 0.010 | Eval Mean: 193.80 | Eval Var: 6674.16
# Q-Net-Alt Episode 282/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 93.80 | Eval Var: 708.16
# Q-Net-Alt Episode 283/500 | Training Reward: 180 | Epsilon: 0.010 | Eval Mean: 56.40 | Eval Var: 141.04
# Q-Net-Alt Episode 284/500 | Training Reward: 209 | Epsilon: 0.010 | Eval Mean: 15.40 | Eval Var: 3.44
# Q-Net-Alt Episode 285/500 | Training Reward: 113 | Epsilon: 0.010 | Eval Mean: 191.60 | Eval Var: 12776.24
# Q-Net-Alt Episode 286/500 | Training Reward: 80 | Epsilon: 0.010 | Eval Mean: 256.40 | Eval Var: 15273.04
# Q-Net-Alt Episode 287/500 | Training Reward: 144 | Epsilon: 0.010 | Eval Mean: 82.80 | Eval Var: 191.36
# Q-Net-Alt Episode 288/500 | Training Reward: 92 | Epsilon: 0.010 | Eval Mean: 71.20 | Eval Var: 10.16
# Q-Net-Alt Episode 289/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 296.40 | Eval Var: 14663.44
# Q-Net-Alt Episode 290/500 | Training Reward: 72 | Epsilon: 0.010 | Eval Mean: 25.80 | Eval Var: 9.76
# Q-Net-Alt Episode 291/500 | Training Reward: 51 | Epsilon: 0.010 | Eval Mean: 48.60 | Eval Var: 11.84
# Q-Net-Alt Episode 292/500 | Training Reward: 41 | Epsilon: 0.010 | Eval Mean: 51.20 | Eval Var: 24.56
# Q-Net-Alt Episode 293/500 | Training Reward: 81 | Epsilon: 0.010 | Eval Mean: 59.00 | Eval Var: 110.40
# Q-Net-Alt Episode 294/500 | Training Reward: 52 | Epsilon: 0.010 | Eval Mean: 117.40 | Eval Var: 11015.84
# Q-Net-Alt Episode 295/500 | Training Reward: 58 | Epsilon: 0.010 | Eval Mean: 56.20 | Eval Var: 20.56
# Q-Net-Alt Episode 296/500 | Training Reward: 43 | Epsilon: 0.010 | Eval Mean: 59.40 | Eval Var: 267.84
# Q-Net-Alt Episode 297/500 | Training Reward: 55 | Epsilon: 0.010 | Eval Mean: 110.80 | Eval Var: 9878.96
# Q-Net-Alt Episode 298/500 | Training Reward: 67 | Epsilon: 0.010 | Eval Mean: 127.20 | Eval Var: 12426.96
# Q-Net-Alt Episode 299/500 | Training Reward: 37 | Epsilon: 0.010 | Eval Mean: 188.80 | Eval Var: 20077.36
# Q-Net-Alt Episode 300/500 | Training Reward: 96 | Epsilon: 0.010 | Eval Mean: 313.20 | Eval Var: 10947.76
# Q-Net-Alt Episode 301/500 | Training Reward: 79 | Epsilon: 0.010 | Eval Mean: 275.00 | Eval Var: 17655.20
# Q-Net-Alt Episode 302/500 | Training Reward: 78 | Epsilon: 0.010 | Eval Mean: 81.20 | Eval Var: 36.56
# Q-Net-Alt Episode 303/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 277.80 | Eval Var: 32916.96
# Q-Net-Alt Episode 304/500 | Training Reward: 162 | Epsilon: 0.010 | Eval Mean: 11.60 | Eval Var: 0.64
# Q-Net-Alt Episode 305/500 | Training Reward: 12 | Epsilon: 0.010 | Eval Mean: 23.60 | Eval Var: 1.84
# Q-Net-Alt Episode 306/500 | Training Reward: 79 | Epsilon: 0.010 | Eval Mean: 19.40 | Eval Var: 3.44
# Q-Net-Alt Episode 307/500 | Training Reward: 26 | Epsilon: 0.010 | Eval Mean: 38.40 | Eval Var: 69.84
# Q-Net-Alt Episode 308/500 | Training Reward: 77 | Epsilon: 0.010 | Eval Mean: 67.80 | Eval Var: 168.16
# Q-Net-Alt Episode 309/500 | Training Reward: 91 | Epsilon: 0.010 | Eval Mean: 83.40 | Eval Var: 353.44
# Q-Net-Alt Episode 310/500 | Training Reward: 263 | Epsilon: 0.010 | Eval Mean: 215.40 | Eval Var: 17621.84
# Q-Net-Alt Episode 311/500 | Training Reward: 64 | Epsilon: 0.010 | Eval Mean: 96.40 | Eval Var: 183.04
# Q-Net-Alt Episode 312/500 | Training Reward: 58 | Epsilon: 0.010 | Eval Mean: 160.40 | Eval Var: 29033.04
# Q-Net-Alt Episode 313/500 | Training Reward: 50 | Epsilon: 0.010 | Eval Mean: 69.00 | Eval Var: 80.80
# Q-Net-Alt Episode 314/500 | Training Reward: 269 | Epsilon: 0.010 | Eval Mean: 190.40 | Eval Var: 24880.24
# Q-Net-Alt Episode 315/500 | Training Reward: 117 | Epsilon: 0.010 | Eval Mean: 70.20 | Eval Var: 218.16
# Q-Net-Alt Episode 316/500 | Training Reward: 55 | Epsilon: 0.010 | Eval Mean: 185.20 | Eval Var: 25813.36
# Q-Net-Alt Episode 317/500 | Training Reward: 85 | Epsilon: 0.010 | Eval Mean: 276.40 | Eval Var: 28507.44
# Q-Net-Alt Episode 318/500 | Training Reward: 88 | Epsilon: 0.010 | Eval Mean: 214.80 | Eval Var: 22303.36
# Q-Net-Alt Episode 319/500 | Training Reward: 100 | Epsilon: 0.010 | Eval Mean: 69.60 | Eval Var: 405.44
# Q-Net-Alt Episode 320/500 | Training Reward: 76 | Epsilon: 0.010 | Eval Mean: 73.20 | Eval Var: 691.76
# Q-Net-Alt Episode 321/500 | Training Reward: 82 | Epsilon: 0.010 | Eval Mean: 67.60 | Eval Var: 410.24
# Q-Net-Alt Episode 322/500 | Training Reward: 78 | Epsilon: 0.010 | Eval Mean: 59.40 | Eval Var: 311.84
# Q-Net-Alt Episode 323/500 | Training Reward: 152 | Epsilon: 0.010 | Eval Mean: 44.60 | Eval Var: 71.04
# Q-Net-Alt Episode 324/500 | Training Reward: 46 | Epsilon: 0.010 | Eval Mean: 177.60 | Eval Var: 28029.04
# Q-Net-Alt Episode 325/500 | Training Reward: 60 | Epsilon: 0.010 | Eval Mean: 54.80 | Eval Var: 124.56
# Q-Net-Alt Episode 326/500 | Training Reward: 70 | Epsilon: 0.010 | Eval Mean: 148.00 | Eval Var: 31025.20
# Q-Net-Alt Episode 327/500 | Training Reward: 51 | Epsilon: 0.010 | Eval Mean: 53.60 | Eval Var: 231.04
# Q-Net-Alt Episode 328/500 | Training Reward: 37 | Epsilon: 0.010 | Eval Mean: 82.40 | Eval Var: 2301.04
# Q-Net-Alt Episode 329/500 | Training Reward: 57 | Epsilon: 0.010 | Eval Mean: 71.00 | Eval Var: 382.40
# Q-Net-Alt Episode 330/500 | Training Reward: 53 | Epsilon: 0.010 | Eval Mean: 67.20 | Eval Var: 262.16
# Q-Net-Alt Episode 331/500 | Training Reward: 55 | Epsilon: 0.010 | Eval Mean: 58.40 | Eval Var: 232.64
# Q-Net-Alt Episode 332/500 | Training Reward: 64 | Epsilon: 0.010 | Eval Mean: 51.20 | Eval Var: 50.96
# Q-Net-Alt Episode 333/500 | Training Reward: 44 | Epsilon: 0.010 | Eval Mean: 54.20 | Eval Var: 230.16
# Q-Net-Alt Episode 334/500 | Training Reward: 60 | Epsilon: 0.010 | Eval Mean: 153.00 | Eval Var: 30277.60
# Q-Net-Alt Episode 335/500 | Training Reward: 128 | Epsilon: 0.010 | Eval Mean: 53.40 | Eval Var: 167.84
# Q-Net-Alt Episode 336/500 | Training Reward: 52 | Epsilon: 0.010 | Eval Mean: 67.00 | Eval Var: 195.20
# Q-Net-Alt Episode 337/500 | Training Reward: 50 | Epsilon: 0.010 | Eval Mean: 61.40 | Eval Var: 201.04
# Q-Net-Alt Episode 338/500 | Training Reward: 74 | Epsilon: 0.010 | Eval Mean: 61.80 | Eval Var: 404.96
# Q-Net-Alt Episode 339/500 | Training Reward: 97 | Epsilon: 0.010 | Eval Mean: 324.40 | Eval Var: 46263.04
# Q-Net-Alt Episode 340/500 | Training Reward: 313 | Epsilon: 0.010 | Eval Mean: 128.00 | Eval Var: 8768.80
# Q-Net-Alt Episode 341/500 | Training Reward: 127 | Epsilon: 0.010 | Eval Mean: 27.80 | Eval Var: 17.36
# Q-Net-Alt Episode 342/500 | Training Reward: 101 | Epsilon: 0.010 | Eval Mean: 22.60 | Eval Var: 9.84
# Q-Net-Alt Episode 343/500 | Training Reward: 318 | Epsilon: 0.010 | Eval Mean: 23.40 | Eval Var: 3.04
# Q-Net-Alt Episode 344/500 | Training Reward: 227 | Epsilon: 0.010 | Eval Mean: 83.20 | Eval Var: 44.96
# Q-Net-Alt Episode 345/500 | Training Reward: 110 | Epsilon: 0.010 | Eval Mean: 109.20 | Eval Var: 1484.96
# Q-Net-Alt Episode 346/500 | Training Reward: 231 | Epsilon: 0.010 | Eval Mean: 113.20 | Eval Var: 3244.56
# Q-Net-Alt Episode 347/500 | Training Reward: 64 | Epsilon: 0.010 | Eval Mean: 71.80 | Eval Var: 51.76
# Q-Net-Alt Episode 348/500 | Training Reward: 101 | Epsilon: 0.010 | Eval Mean: 48.20 | Eval Var: 92.56
# Q-Net-Alt Episode 349/500 | Training Reward: 49 | Epsilon: 0.010 | Eval Mean: 61.20 | Eval Var: 140.56
# Q-Net-Alt Episode 350/500 | Training Reward: 76 | Epsilon: 0.010 | Eval Mean: 66.20 | Eval Var: 12.56
# Q-Net-Alt Episode 351/500 | Training Reward: 79 | Epsilon: 0.010 | Eval Mean: 87.60 | Eval Var: 315.44
# Q-Net-Alt Episode 352/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 98.80 | Eval Var: 192.96
# Q-Net-Alt Episode 353/500 | Training Reward: 192 | Epsilon: 0.010 | Eval Mean: 13.40 | Eval Var: 3.84
# Q-Net-Alt Episode 354/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 159.40 | Eval Var: 39.04
# Q-Net-Alt Episode 355/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 136.20 | Eval Var: 26.96
# Q-Net-Alt Episode 356/500 | Training Reward: 224 | Epsilon: 0.010 | Eval Mean: 262.80 | Eval Var: 429.76
# Q-Net-Alt Episode 357/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 490.80 | Eval Var: 128.56
# Q-Net-Alt Episode 358/500 | Training Reward: 384 | Epsilon: 0.010 | Eval Mean: 143.80 | Eval Var: 4034.56
# Q-Net-Alt Episode 359/500 | Training Reward: 500 | Epsilon: 0.010 | Eval Mean: 500.00 | Eval Var: 0.00
#
# Early Stopping Triggered! Converged at Episode 359
#
# Average Training Time per Episode Q-Net-Alt: 9.4157 seconds

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative Naive Q-Network policies

# %%
## 基线与替代策略性能对比
import pandas as pd

# 整理对比数据
comparison_data = {
    "指标": [
        "最终评估均值", 
        "最终评估方差", 
        "平均每轮训练时间（秒）", 
        "收敛轮次（达到500分）"
    ],
    "基线策略": [
        eval_reward_mean_lst[-1],  # 最后一轮的评估均值
        eval_reward_var_lst[-1],   # 最后一轮的评估方差
        avg_train_time,
        len(train_reward_lst)      # 总训练轮次（早停则为早停轮次）
    ],
    "替代策略": [
        eval_reward_mean_lst_alt[-1],
        eval_reward_var_lst_alt[-1],
        avg_train_time_alt,
        len(train_reward_lst_alt)
    ]
}

# 转换为表格并打印
df = pd.DataFrame(comparison_data)
print("\n===== 基线策略与替代策略对比 =====")
print(df.round(3))  # 保留3位小数

# 绘制移动平均奖励对比图
plt.figure(figsize=(10, 5))
# 基线策略平滑奖励
smoothed_base = np.convolve(train_reward_lst, np.ones(20)/20, mode='valid')
episodes_base = np.arange(20, len(train_reward_lst) + 1)
# 替代策略平滑奖励
smoothed_alt = np.convolve(train_reward_lst_alt, np.ones(20)/20, mode='valid')
episodes_alt = np.arange(20, len(train_reward_lst_alt) + 1)

plt.plot(episodes_base, smoothed_base, label='基线策略', color='blue')
plt.plot(episodes_alt, smoothed_alt, label='替代策略', color='green')
plt.xlabel('训练轮次')
plt.ylabel('平滑训练奖励（窗口=20）')
plt.title('基线策略与替代策略的平滑训练奖励对比')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Experience Replay Framework
#
# By now, you may have noticed that in a standard RL setup, the agent **only learns from its most recent experience** at each step. This makes training unstable and inefficient. Additionally, consecutive experiences are often highly correlated, which can lead to poor generalization.
#
# To address this, we will adopt the **Experience Replay Framework**, where past interactions are stored in a **Replay Buffer** and **a randomly sampled batch** is used to update the decision-making policy. This helps to:
#
# - **Break correlation** between consecutive experiences, stabilizing learning.
# - **Improve data efficiency** by reusing past experiences multiple times.
# - **Smooth training updates**, preventing abrupt policy changes.
#
# The figure below illustrates this process:
# ![dqn-agent.png](attachment:a59a0ba3-95f7-4a60-baa3-bbb9c924e972.png)
#
# - The Agent interacts with the Environment, taking actions based on its learned policy.
# - The Replay Buffer stores past experiences `(state, action, reward, next state, done)`.
# - Instead of updating after every step, the agent samples from the buffer and learns from past interactions.
#
# This framework is used in naive DQN, DQN and DDQN to stabilize Q-learning.

# %% [markdown]
# ## Implement Replay Buffer and Functions

# %%
# Store (state, action, reward, next_state, done)
def store_experience(replay_buffer, state, action, reward, next_stat, done):
        replay_buffer.append((state, action, reward, next_state, done))

# Sample (state, action, reward, next_state, done) mini-batch for training
def sample_experience(replay_buffer, batch_size):

    # Ensure we have enough samples
    assert len(replay_buffer) >= batch_size, (
        f"Not enough samples in buffer to sample {batch_size} items.")

    # Sample a mini-batch
    minibatch = random.sample(replay_buffer, batch_size)

    states, actions, rewards, next_states, dones = zip(*minibatch)

    states = np.array(states, dtype=np.float32).squeeze()
    next_states = np.array(next_states, dtype=np.float32).squeeze()
    actions = np.array(actions, dtype=np.int32)
    rewards = np.array(rewards, dtype=np.float32)
    dones = np.array(dones, dtype=np.float32)

    return states, actions, rewards, next_states, dones

# [Hint] You may find the following statements useful
"""
# Define replay buffer
replay_buffer = deque(maxlen=10000)

# Store experience tuple into replay_buffer
store_experience(replay_buffer, state, action, reward, next_state, done)

# Sample mini-batch of size ba from replay_buffer
states, actions, rewards, next_states, dones = sample_experience(replay_buffer, ba)
"""
# Out:
# '\n# Define replay buffer\nreplay_buffer = deque(maxlen=10000)\n\n# Store experience tuple into replay_buffer\nstore_experience(replay_buffer, state, action, reward, next_state, done)\n\n# Sample mini-batch of size ba from replay_buffer\nstates, actions, rewards, next_states, dones = sample_experience(replay_buffer, ba)\n'

# %% [markdown]
# # Naive DQN - Baseline
#
# In this section, you will complete the Naive DQN alorithm by implementing the missing components marked as `[WriteCode]`.

# %% [markdown]
# ## Define and Compile the Neural Network
#
# A single network $Q_\theta$ (parameterized by $\theta$) is used to approximate $Q(s,a)$.
#
# The target used by Naive DQN is then:
#
# $Y^{NaiveQ}_t = R_{t+1} + \gamma Q_{\theta}(S_{t+1}, a)$

# %%
# Naive DQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...

# Define the Q-network
model = Sequential()

# [WriteCode]
# model.add(...

# Compile the model
# [WriteCode]

# Print the model summary
# [WriteCode]

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "naive_dqn_baseline"  # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# For timing training
total_training_time = 0

# Define replay buffer
# [WriteCode]
# replay_buffer = ...

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):
        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            pass # remove pass and use 2 lines below
#            q_values = model.predict(state, verbose=0)
#            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]

        state = next_state
        total_reward += reward

        if done:
            break


#        if len(replay_buffer) >= ba:
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Q-Learning update:  Q(s, a) = r + gamma * max Q(s', a')
            # [WriteCode]

            # Hints:

            # 1. Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * max(Q(next_state, a))

            # 2. Predict current Q-values for state
            # Update only the Q-value for the taken action

            # 3. Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)

            # Update exploration rate
            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]


    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}")
#        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
#        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
#    eval_reward_mean_lst.append(eval_reward_mean)
#    eval_reward_var_lst.append(eval_reward_var)
#    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
#    if eval_reward_mean > 500: # [Modify this threshold as needed]
#        print(f"Early stopping triggered at Episode {ep + 1}.")
#        break

# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# Episode 1/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 2/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 3/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 4/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 5/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 6/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 7/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 8/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 9/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 10/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 11/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 12/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 13/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 14/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 15/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 16/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 17/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 18/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 19/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 20/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 21/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 22/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 23/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 24/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 25/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 26/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 27/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 28/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 29/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 30/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 31/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 32/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 33/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 34/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 35/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 36/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 37/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 38/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 39/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 40/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 41/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 42/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 43/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 44/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 45/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 46/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 47/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 48/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 49/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 50/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 51/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 52/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 53/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 54/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 55/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 56/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 57/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 58/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 59/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 60/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 61/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 62/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 63/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 64/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 65/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 66/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 67/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 68/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 69/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 70/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 71/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 72/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 73/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 74/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 75/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 76/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 77/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 78/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 79/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 80/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 81/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 82/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 83/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 84/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 85/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 86/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 87/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 88/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 89/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 90/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 91/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 92/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 93/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 94/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 95/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 96/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 97/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 98/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 99/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 100/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 101/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 102/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 103/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 104/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 105/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 106/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 107/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 108/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 109/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 110/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 111/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 112/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 113/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 114/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 115/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 116/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 117/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 118/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 119/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 120/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 121/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 122/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 123/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 124/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 125/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 126/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 127/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 128/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 129/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 130/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 131/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 132/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 133/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 134/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 135/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 136/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 137/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 138/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 139/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 140/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 141/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 142/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 143/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 144/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 145/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 146/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 147/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 148/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 149/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 150/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 151/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 152/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 153/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 154/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 155/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 156/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 157/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 158/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 159/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 160/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 161/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 162/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 163/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 164/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 165/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 166/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 167/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 168/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 169/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 170/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 171/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 172/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 173/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 174/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 175/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 176/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 177/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 178/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 179/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 180/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 181/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 182/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 183/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 184/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 185/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 186/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 187/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 188/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 189/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 191/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 192/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 193/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 194/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 195/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 196/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 197/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 198/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 199/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 200/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 201/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 202/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 203/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 204/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 205/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 206/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 207/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 208/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 209/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 210/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 211/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 212/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 213/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 214/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 215/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 216/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 217/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 218/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 219/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 220/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 221/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 222/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 224/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 225/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 226/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 227/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 228/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 229/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 230/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 231/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 232/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 233/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 234/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 235/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 236/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 237/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 238/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 239/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 240/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 241/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 242/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 243/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 244/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 245/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 246/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 247/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 248/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 249/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 250/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Training time: 0.0001 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...

# plot_eval_rwd_mean(...

# plot_eval_rwd_var(...

# %% [markdown]
# # Naive DQN - Alternative
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative Naive DQN Policies

# %%
# [Write Code]

# %% [markdown]
# # DQN
#
# In this section, you will complete the DQN algorithm by implementing the missing components marked as `[WriteCode]`.

# %% [markdown]
# ## Define and Compile the Neural Networks

# %% [markdown]
# The standard DQN [https://arxiv.org/abs/1312.5602] approach features a periodically updated target network to stabilize training:
#
# - `target_model`: A periodically updated network that stabilizes training. During training, this network is used to compute $Q(S_{t+1}, a)$ for each possible action $a$. This network is not actively trained, but at regular intervals, its weights are copied from `eval_model`. This prevents rapid fluctuations in target Q-values and improves learning stability.
#
# - `eval_model`: The online learning network that interacts with the environment. During training, this network is used to compute $Q(S_{t}, a)$ for each possible action $a$. It updates its weights by minimizing the difference between predicted and target Q-values, improving the agent's decision-making over time.
#
# The target used by DQN is then:
#
# $Y^{Q}_t = R_{t+1} + \gamma \max_a Q_{target}(S_{t+1}, a)$
#
# In the following section, define `[eval_model]` and `[target_model]` with identical architectures.

# %%
# DQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...

# Define the eval (online) network
eval_model = Sequential()

# [WriteCode]
# model.add(...

# Compile the model
# [WriteCode]

# Print the model summary
# [WriteCode]


# Create target_model with the same architecture
target_model = Sequential()

# [WriteCode]
# model.add(...

# Skip compiling as target_model will not be trained with .fit()
# Instead, weights will be copied from the online model
target_model.set_weights(eval_model.get_weights())

# Print the model summary
# [WriteCode]
print(target_model.summary())
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Set Up Env and Train the Policy

# %% [markdown]
# In this section, you will complete the DQN training routine by implementing the missing components marked as `[WriteCode]`.

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "dqn_baseline"   # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# Train Counter for weight syncing
train_counter = 0

# For timing training
total_training_time = 0

# Define replay buffer
# replay_buffer = ...

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):
        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            pass # remove pass and 2 lines below
#            q_values = eval_model.predict(state, verbose=0)
#            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]

        state = next_state
        total_reward += reward

        if done:
            break

        # if len(replay_buffer) >= ba:
            # train_counter += 1
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Deep Q-Learning update: Q(s, a) = r + gamma * max Q_target(S', a)
            # [WriteCode]

            # Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * max(Q_target(next_state, a))

            # Predict current Q-values for state using eval_model
            # Predict future Q-values using target_model (NOT eval_model)

            # Update only the Q-value for the taken action

            # Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)


            # Update exploration rate
            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

            # Periodically update the target network
            if train_counter % target_update_freq == 0:
                target_model.set_weights(eval_model.get_weights())

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]

    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}")
#        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
#        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
#    eval_reward_mean_lst.append(eval_reward_mean)
#    eval_reward_var_lst.append(eval_reward_var)
#    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
#    if eval_reward_mean > 500: # [Modify this threshold as needed]
#        print(f"Early stopping triggered at Episode {ep + 1}.")
#        break

# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# Episode 1/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 2/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 3/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 4/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 5/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 6/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 7/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 8/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 9/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 10/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 11/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 12/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 13/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 14/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 15/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 16/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 17/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 18/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 19/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 20/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 21/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 22/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 23/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 24/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 25/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 26/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 27/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 28/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 29/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 30/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 31/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 32/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 33/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 34/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 35/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 36/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 37/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 38/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 39/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 40/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 41/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 42/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 43/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 44/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 45/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 46/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 47/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 48/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 49/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 50/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 51/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 52/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 53/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 54/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 55/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 56/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 57/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 58/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 59/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 60/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 61/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 62/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 63/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 64/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 65/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 66/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 67/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 68/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 69/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 70/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 71/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 72/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 73/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 74/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 75/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 76/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 77/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 78/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 79/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 80/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 81/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 82/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 83/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 84/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 85/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 86/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 87/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 88/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 89/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 90/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 91/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 92/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 93/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 94/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 95/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 96/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 97/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 98/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 99/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 100/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 101/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 102/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 103/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 104/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 105/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 106/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 107/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 108/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 109/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 110/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 111/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 112/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 113/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 114/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 115/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 116/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 117/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 118/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 119/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 120/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 121/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 122/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 123/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 124/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 125/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 126/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 127/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 128/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 129/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 130/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 131/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 132/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 133/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 134/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 135/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 136/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 137/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 138/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 139/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 140/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 141/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 142/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 143/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 144/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 145/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 146/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 147/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 148/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 149/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 150/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 151/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 152/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 153/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 154/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 155/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 156/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 157/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 158/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 159/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 160/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 161/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 162/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 163/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 164/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 165/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 166/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 167/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 168/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 169/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 170/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 171/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 172/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 173/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 174/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 175/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 176/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 177/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 178/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 179/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 180/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 181/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 182/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 183/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 184/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 185/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 186/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 187/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 188/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 189/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 191/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 192/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 193/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 194/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 195/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 196/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 197/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 198/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 199/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 200/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 201/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 202/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 203/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 204/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 205/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 206/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 207/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 208/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 209/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 210/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 211/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 212/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 213/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 214/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 215/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 216/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 217/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 218/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 219/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 220/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 221/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 222/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 224/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 225/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 226/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 227/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 228/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 229/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 230/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 231/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 232/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 233/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 234/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 235/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 236/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 237/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 238/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 239/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 240/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 241/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 242/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 243/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 244/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 245/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 246/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 247/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 248/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 249/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 250/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Training time: 0.0001 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]
plot_smoothed_training_rwd(train_reward_lst, window_size=20)
plot_eval_rwd_mean(eval_reward_mean_lst)
plot_eval_rwd_var(eval_reward_var_lst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       1 # Write code to plot
#       2 # 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
#       3 # [Write Code]
# ----> 4 plot_smoothed_training_rwd(train_reward_lst, window_size=20)
#       5 plot_eval_rwd_mean(eval_reward_mean_lst)
#       6 plot_eval_rwd_var(eval_reward_var_lst)
#
# Cell In[50], line 61, in plot_smoothed_training_rwd(train_rwd_list, window_size)
#      53 """
#      54 计算并绘制窗口大小为20的移动平均训练奖励曲线
#      55 参数:
#      56     train_rwd_list: 训练奖励列表，每个元素为一轮训练的总奖励
#      57     window_size: 移动平均窗口大小（固定为20）
#      58 """
#      59 # 计算移动平均：使用卷积实现窗口内均值，mode='valid'确保只保留完整窗口的结果
#      60 # 例如：前19轮无平滑结果，从第20轮开始有值
# ---> 61 smoothed_rewards = np.convolve(
#      62     train_rwd_list,
#      63     np.ones(window_size) / window_size,  # 窗口内权重平均
#      64     mode='valid'
#      65 )
#      66 # 生成对应的训练轮次索引（与平滑结果对齐）
#      67 episodes = np.arange(window_size, len(train_rwd_list) + 1)  # 起始轮次为window_size
#
# File /opt/miniconda3/lib/python3.13/site-packages/numpy/_core/numeric.py:902, in convolve(a, v, mode)
#     900     raise ValueError('a cannot be empty')
#     901 if len(v) == 0:
# --> 902     raise ValueError('v cannot be empty')
#     903 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: v cannot be empty

# %% [markdown]
# # DQN - Alternative
#
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...

# plot_eval_rwd_mean(...

# plot_eval_rwd_var(...

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative DQN Policies

# %%
# [Write Code]

# %% [markdown]
# # DDQN

# %% [markdown]
# ## Define and Compile the Neural Networks
#
# The Double Deep Q-Network (DDQN) [https://arxiv.org/abs/1509.06461] improves upon standard DQN by reducing overestimation bias in Q-values. DDQN achieves this by decoupling action selection from value estimation using two networks, which is almost identical as DQN:
#
# - `target_model`: A periodically updated network that stabilizes training. During training, this network is used to compute $Q(S_{t+1}, a)$ for each possible action $a$. This network is also not trained but synced from `eval_model`. **However, unlike DQN, this network is only used to evaluate the Q-value of the action chosen by `eval_model`, making value updates more stable.**
#
# - `eval_model`: The online learning network that interacts with the environment. During training, this network is used to select the best action using $\arg\max_a Q(S_{t}, a)$ and updates its weights by minimizing the difference between predicted and target Q-value.
#
# The target used by DDQN is then:
#
# $Y^{Q}_t = R_{t+1} + \gamma Q_{target}(S_{t+1}, \arg \max_{a} Q_{eval}(S_{t+1}, a))$

# %%
# DDQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...

# Define the eval (online) network
eval_model = Sequential()

# [WriteCode]
# model.add(...

# Compile the model
# [WriteCode]

# Print the model summary
# [WriteCode]



# Create target_model with the same architecture
target_model = Sequential()

# [WriteCode]
# model.add(...

# Skip compiling as target_model will not be trained with .fit()
# Instead, weights will be copied from the online model
# target_model.set_weights(eval_model.get_weights())

# Print the model summary
# [WriteCode]

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "ddqn_baseline"  # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# Train Counter for weight syncing
train_counter = 0

# For timing training
total_training_time = 0

# Define replay buffer
# replay_buffer = ...

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):

        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            pass # remove pass and use 2 lines below
#            q_values = eval_model.predict(state, verbose=0)
#            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]

        state = next_state
        total_reward += reward

        if done:
            break

#        if len(replay_buffer) >= ba:
#            train_counter += 1
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Double Deep Q-Learning update:
            # Q(s, a) = r + gamma * Q_target(S', argmax Q_eval(S', a))
            # [WriteCode]

            # Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * Q_target(S', argmax Q_eval(S', a))

            # Predict current Q-values for state using eval_model
            # Use eval_model to determine best action in next_state
            # Use target_model to compute Q-value for that action

            # Update only the Q-value for the taken action

            # Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)


            # Update exploration rate
            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

            # Periodically update the target network
 #           if train_counter % target_update_freq == 0:
 #               target_model.set_weights(eval_model.get_weights())

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]

    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}")
#        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
#        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
#    eval_reward_mean_lst.append(eval_reward_mean)
#    eval_reward_var_lst.append(eval_reward_var)
    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
#    if eval_reward_mean > 500: # [Modify this threshold as needed]
#        print(f"Early stopping triggered at Episode {ep + 1}.")
#        break

# record end time and calculate average training time per episode
# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# Episode 1/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 2/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 3/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 4/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 5/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 6/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 7/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 8/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 9/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 10/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 11/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 12/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 13/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 14/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 15/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 16/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 17/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 18/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 19/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 20/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 21/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 22/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 23/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 24/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 25/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 26/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 27/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 28/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 29/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 30/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 31/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 32/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 33/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 34/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 35/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 36/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 37/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 38/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 39/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 40/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 41/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 42/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 43/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 44/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 45/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 46/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 47/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 48/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 49/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 50/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 51/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 52/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 53/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 54/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 55/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 56/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 57/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 58/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 59/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 60/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 61/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 62/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 63/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 64/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 65/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 66/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 67/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 68/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 69/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 70/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 71/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 72/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 73/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 74/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 75/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 76/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 77/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 78/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 79/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 80/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 81/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 82/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 83/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 84/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 85/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 86/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 87/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 88/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 89/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 90/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 91/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 92/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 93/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 94/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 95/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 96/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 97/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 98/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 99/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 100/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 101/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 102/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 103/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 104/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 105/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 106/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 107/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 108/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 109/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 110/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 111/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 112/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 113/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 114/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 115/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 116/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 117/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 118/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 119/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 120/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 121/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 122/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 123/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 124/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 125/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 126/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 127/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 128/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 129/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 130/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 131/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 132/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 133/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 134/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 135/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 136/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 137/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 138/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 139/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 140/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 141/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 142/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 143/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 144/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 145/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 146/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 147/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 148/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 149/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 150/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 151/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 152/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 153/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 154/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 155/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 156/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 157/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 158/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 159/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 160/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 161/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 162/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 163/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 164/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 165/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 166/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 167/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 168/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 169/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 170/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 171/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 172/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 173/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 174/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 175/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 176/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 177/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 178/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 179/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 180/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 181/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 182/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 183/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 184/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 185/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 186/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 187/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 188/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 189/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 191/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 192/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 193/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 194/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 195/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 196/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 197/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 198/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 199/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 200/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 201/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 202/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 203/250 | Ep. Total Reward: 11.0 | Epsilon : 0.000
# Episode 204/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 205/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 206/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 207/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 208/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 209/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 210/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 211/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 212/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 213/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 214/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 215/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 216/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 217/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 218/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 219/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 220/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 221/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 222/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 224/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 225/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 226/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 227/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 228/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 229/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 230/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 231/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 232/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 233/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 234/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 235/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 236/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 237/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 238/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 239/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 240/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 241/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 242/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 243/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 244/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 245/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 246/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 247/250 | Ep. Total Reward: 9.0 | Epsilon : 0.000
# Episode 248/250 | Ep. Total Reward: 8.0 | Epsilon : 0.000
# Episode 249/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Episode 250/250 | Ep. Total Reward: 10.0 | Epsilon : 0.000
# Training time: 0.0001 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...

# plot_eval_rwd_mean(...

# plot_eval_rwd_var(...

# %% [markdown]
# # DDQN - Alternative
#
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative DDQN Policies

# %%
# [Write Code]

# %% [markdown]
# # Visualize with Tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./eec4400_logs --port=6006
# Out:
#       <iframe id="tensorboard-frame-13bf8d090d73c030" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-13bf8d090d73c030");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Comparison Across Four Alternative Policies
#
# Compare hyperparameters and performance of the four alternative policies.
#
# You may insert extra cells in the notebook to tabulate/plot/log results effectively.

# %%
# [Write Code]
